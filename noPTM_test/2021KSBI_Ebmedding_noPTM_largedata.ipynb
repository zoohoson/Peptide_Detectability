# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df_aaindex = pd.read_csv('../data/aaindex/df_aaindex19.csv')
print(df_aaindex.shape)
df_aaindex.head(1)
tmp = df_aaindex.drop('Unnamed: 0',axis=1).T
aa2val = dict()
for aa, val in zip(tmp.index, tmp.values):
    aa2val[aa]=val
# Out:
# (19, 21)

# %%
df_detect_peptide_train = pd.read_csv('../data/df_detect_peptide_train_noptm_210930_includeDigest.csv')
test = pd.read_csv('../data/df_detect_peptide_test_noptm_210930_includeDigest.csv')
train, val = train_test_split(df_detect_peptide_train, test_size=0.2, random_state=7)

# %%
train.head(1)
# Out:
#                             peptide               En               Ec  \
# 63979  K.QVTTAENLKDQTVYIVLDKAEYLR.D  NDFVRLFKQVTTAEN  LDKAEYLRDMEANLL
#
#                     E1               E2               protein  \
# 63979  VTTAENLKDQTVYIV  TVYIVLDKAEYLRDM  sp|O43913|ORC5_HUMAN
#
#                             PEP  ID
# 63979  QVTTAENLKDQTVYIVLDKAEYLR   1

# %%
def get_data_labelEnc(df):
    label_enc = {v:k+1 for k, v in enumerate('ARNDCQEGHILKMFPSTWYV')}
    label_enc['Z']=0
    aa_data = [np.array([seq.count(a) for a in 'ARNDCQEGHILKMFPSTWYV'] + list(np.array([aa2val[aa] for aa in seq]).sum(axis=0)))
               for seq in df.PEP.values]
    pep_data = [[label_enc[aa] for aa in seq] + [0]*(30-len(seq))
               for seq in df.PEP.values]
    en_data = [[label_enc[aa] for aa in seq]
               for seq in df.En.values]
    ec_data = [[label_enc[aa] for aa in seq]
               for seq in df.Ec.values]
    e1_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E1.values]
    e2_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E2.values]
    return np.array(aa_data), np.array(pep_data), np.array(en_data), np.array(ec_data), np.array(e1_data), np.array(e2_data), np.array(df.ID.values)

# %%
aa_train, pep_train, en_train, ec_train, e1_train, e2_train, y_train = get_data_labelEnc(train)
aa_val, pep_val, en_val, ec_val, e1_val, e2_val, y_val = get_data_labelEnc(val)
aa_test, pep_test, en_test, ec_test, e1_test, e2_test, y_test = get_data_labelEnc(test)
print(aa_train.shape, pep_train.shape, en_train.shape, ec_train.shape, e1_train.shape, e2_train.shape, y_train.shape)
print(aa_val.shape, pep_val.shape, en_val.shape, ec_val.shape, e1_val.shape, e2_val.shape, y_val.shape)
print(aa_test.shape, pep_test.shape, en_test.shape, ec_test.shape, e1_test.shape, e2_test.shape, y_test.shape)
# Out:
# (337179, 39) (337179, 30) (337179, 15) (337179, 15) (337179, 15) (337179, 15) (337179,)
# (84295, 39) (84295, 30) (84295, 15) (84295, 15) (84295, 15) (84295, 15) (84295,)
# (88998, 39) (88998, 30) (88998, 15) (88998, 15) (88998, 15) (88998, 15) (88998,)

# %% [markdown]
# # Train

# %%
from tensorflow.python.client import device_lib

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*4)])
    except RuntimeError as e:
        print(e)

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# # high param

# %%
pep = tf.keras.layers.Input(shape=((30,)))
input1_ = tf.keras.layers.Embedding(21, 32, input_length=30, mask_zero=True)(pep)
input1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input1_)

input2 = tf.keras.layers.Input(shape=((39,)))  # peptide info

n = tf.keras.layers.Input(shape=((15,)))
input3_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(n)
input3 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input3_)

c = tf.keras.layers.Input(shape=((15,)))
input4_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(c)
input4 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input4_)

m1 = tf.keras.layers.Input(shape=((15,)))
input5_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m1)
input5 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input5_)

m2 = tf.keras.layers.Input(shape=((15,)))
input6_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m2)
input6 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input6_)







cnn1 = tf.keras.layers.Conv1D(filters=16, kernel_size=3, strides=1, padding='same')(input1)
lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16))(cnn1)
net_lstm_ = tf.keras.layers.Dense(16, activation='relu')(lstm1)
net_lstm = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_lstm_)

net_dense1_ = tf.keras.layers.Dense(32, activation='relu')(input2)
net_dense1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_dense1_)

cnn3 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input3)
digest_n = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn3)
net_n_ = tf.keras.layers.Dense(8, activation='relu')(digest_n)
net_n = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_n_)

cnn4 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input4)
digest_c = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn4)
net_c_ = tf.keras.layers.Dense(8, activation='relu')(digest_c)
net_c = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_c_)

cnn5 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input5)
digest_m1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn5)
net_m1_ = tf.keras.layers.Dense(8, activation='relu')(digest_m1)
net_m1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m1_)

cnn6 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input6)
digest_m2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn6)
net_m2_ = tf.keras.layers.Dense(8, activation='relu')(digest_m2)
net_m2 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m2_)








merge = tf.keras.layers.concatenate([net_lstm, 
                                     net_dense1,
                                     net_n,
                                     net_c,
                                     net_m1,
                                     net_m2])

net1 = tf.keras.layers.Dense(64, activation='relu')(merge)
net1_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net1)
net3 = tf.keras.layers.Dense(32, activation='relu')(net1_drop)
net3_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net3)

output = tf.keras.layers.Dense(1, activation = 'sigmoid')(net3_drop)

model_high = tf.keras.Model(inputs=[pep, input2,
                              n, c,
                              m1, m2],
                       outputs=[output])

model_high.summary()

model_high.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      mode='min', 
                                      verbose=1,
                                      patience=50)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 32)       672         input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 15, 16)       336         input_3[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 15, 16)       336         input_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 15, 16)       336         input_5[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 15, 16)       336         input_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 32)       0           embedding[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 15, 16)       0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 16)       0           embedding_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 15, 16)       0           embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 16)       0           embedding_4[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 30, 16)       1552        dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 15, 8)        392         dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 15, 8)        392         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 15, 8)        392         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 15, 8)        392         dropout_4[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 32)           4224        conv1d[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 16)           1088        conv1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 16)           1088        conv1d_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 16)           1088        conv1d_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 16)           1088        conv1d_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           528         bidirectional[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           1280        input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            136         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 8)            136         bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 8)            136         bidirectional_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 8)            136         bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16)           0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8)            0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80)           0           dropout_5[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
#                                                                  dropout_8[0][0]
#                                                                  dropout_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           5184        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           2080        dropout_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            33          dropout_12[0][0]
# ==================================================================================================
# Total params: 23,361
# Trainable params: 23,361
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model_high.fit([pep_train, aa_train, en_train, ec_train, e1_train, e2_train],
                    y_train, 
                    epochs=300,
                    batch_size=128,
                    validation_data=([pep_val, aa_val, en_val, ec_val, e1_val, e2_val], y_val),
                    callbacks=[es]
                        )
# Out:
# Epoch 1/300
# 2635/2635 [==============================] - 148s 50ms/step - loss: 4.4557 - accuracy: 0.5531 - val_loss: 0.4578 - val_accuracy: 0.7739
# Epoch 2/300
# 2635/2635 [==============================] - 141s 53ms/step - loss: 0.5037 - accuracy: 0.7650 - val_loss: 0.4085 - val_accuracy: 0.7991
# Epoch 3/300
# 2635/2635 [==============================] - 144s 55ms/step - loss: 0.4167 - accuracy: 0.8023 - val_loss: 0.3866 - val_accuracy: 0.8178
# Epoch 4/300
# 2635/2635 [==============================] - 157s 60ms/step - loss: 0.3988 - accuracy: 0.8133 - val_loss: 0.3832 - val_accuracy: 0.8186
# Epoch 5/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3896 - accuracy: 0.8188 - val_loss: 0.3719 - val_accuracy: 0.8256
# Epoch 6/300
# 2635/2635 [==============================] - 173s 65ms/step - loss: 0.3796 - accuracy: 0.8235 - val_loss: 0.3649 - val_accuracy: 0.8316
# Epoch 7/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3717 - accuracy: 0.8287 - val_loss: 0.3622 - val_accuracy: 0.8301
# Epoch 8/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3646 - accuracy: 0.8322 - val_loss: 0.3512 - val_accuracy: 0.8388
# Epoch 9/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3579 - accuracy: 0.8363 - val_loss: 0.3471 - val_accuracy: 0.8406
# Epoch 10/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3539 - accuracy: 0.8383 - val_loss: 0.3456 - val_accuracy: 0.8415
# Epoch 11/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3488 - accuracy: 0.8408 - val_loss: 0.3428 - val_accuracy: 0.8433
# Epoch 12/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3450 - accuracy: 0.8427 - val_loss: 0.3399 - val_accuracy: 0.8459
# Epoch 13/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3432 - accuracy: 0.8440 - val_loss: 0.3377 - val_accuracy: 0.8460
# Epoch 14/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3417 - accuracy: 0.8448 - val_loss: 0.3353 - val_accuracy: 0.8476
# Epoch 15/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3394 - accuracy: 0.8461 - val_loss: 0.3335 - val_accuracy: 0.8483
# Epoch 16/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3363 - accuracy: 0.8473 - val_loss: 0.3319 - val_accuracy: 0.8499
# Epoch 17/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3349 - accuracy: 0.8474 - val_loss: 0.3328 - val_accuracy: 0.8498
# Epoch 18/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3352 - accuracy: 0.8478 - val_loss: 0.3301 - val_accuracy: 0.8505
# Epoch 19/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3339 - accuracy: 0.8485 - val_loss: 0.3284 - val_accuracy: 0.8505
# Epoch 20/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3304 - accuracy: 0.8505 - val_loss: 0.3278 - val_accuracy: 0.8514
# Epoch 21/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3307 - accuracy: 0.8502 - val_loss: 0.3286 - val_accuracy: 0.8507
# Epoch 22/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3294 - accuracy: 0.8521 - val_loss: 0.3269 - val_accuracy: 0.8522
# Epoch 23/300
# 2635/2635 [==============================] - 173s 65ms/step - loss: 0.3298 - accuracy: 0.8511 - val_loss: 0.3271 - val_accuracy: 0.8530
# Epoch 24/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3278 - accuracy: 0.8521 - val_loss: 0.3258 - val_accuracy: 0.8536
# Epoch 25/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3265 - accuracy: 0.8526 - val_loss: 0.3250 - val_accuracy: 0.8533
# Epoch 26/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3259 - accuracy: 0.8537 - val_loss: 0.3262 - val_accuracy: 0.8531
# Epoch 27/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3257 - accuracy: 0.8533 - val_loss: 0.3256 - val_accuracy: 0.8543
# Epoch 28/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3262 - accuracy: 0.8532 - val_loss: 0.3259 - val_accuracy: 0.8531
# Epoch 29/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3257 - accuracy: 0.8531 - val_loss: 0.3233 - val_accuracy: 0.8547
# Epoch 30/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3239 - accuracy: 0.8544 - val_loss: 0.3228 - val_accuracy: 0.8563
# Epoch 31/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3224 - accuracy: 0.8551 - val_loss: 0.3227 - val_accuracy: 0.8554
# Epoch 32/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3228 - accuracy: 0.8552 - val_loss: 0.3242 - val_accuracy: 0.8552
# Epoch 33/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3220 - accuracy: 0.8555 - val_loss: 0.3213 - val_accuracy: 0.8556
# Epoch 34/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3221 - accuracy: 0.8547 - val_loss: 0.3231 - val_accuracy: 0.8562
# Epoch 35/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3233 - accuracy: 0.8555 - val_loss: 0.3213 - val_accuracy: 0.8557
# Epoch 36/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3215 - accuracy: 0.8553 - val_loss: 0.3212 - val_accuracy: 0.8560
# Epoch 37/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3220 - accuracy: 0.8556 - val_loss: 0.3210 - val_accuracy: 0.8565
# Epoch 38/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3206 - accuracy: 0.8565 - val_loss: 0.3206 - val_accuracy: 0.8568
# Epoch 39/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3204 - accuracy: 0.8565 - val_loss: 0.3190 - val_accuracy: 0.8574
# Epoch 40/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3207 - accuracy: 0.8560 - val_loss: 0.3184 - val_accuracy: 0.8579
# Epoch 41/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3199 - accuracy: 0.8566 - val_loss: 0.3275 - val_accuracy: 0.8535
# Epoch 42/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3195 - accuracy: 0.8562 - val_loss: 0.3193 - val_accuracy: 0.8568
# Epoch 43/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3187 - accuracy: 0.8574 - val_loss: 0.3192 - val_accuracy: 0.8578
# Epoch 44/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3186 - accuracy: 0.8568 - val_loss: 0.3195 - val_accuracy: 0.8570
# Epoch 45/300
# 2635/2635 [==============================] - 173s 65ms/step - loss: 0.3181 - accuracy: 0.8580 - val_loss: 0.3175 - val_accuracy: 0.8583
# Epoch 46/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3180 - accuracy: 0.8579 - val_loss: 0.3196 - val_accuracy: 0.8569
# Epoch 47/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3174 - accuracy: 0.8582 - val_loss: 0.3194 - val_accuracy: 0.8580
# Epoch 48/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3190 - accuracy: 0.8567 - val_loss: 0.3181 - val_accuracy: 0.8564
# Epoch 49/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3172 - accuracy: 0.8586 - val_loss: 0.3166 - val_accuracy: 0.8582
# Epoch 50/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3171 - accuracy: 0.8581 - val_loss: 0.3177 - val_accuracy: 0.8584
# Epoch 51/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3171 - accuracy: 0.8579 - val_loss: 0.3167 - val_accuracy: 0.8583
# Epoch 52/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3168 - accuracy: 0.8582 - val_loss: 0.3169 - val_accuracy: 0.8573
# Epoch 53/300
# 2635/2635 [==============================] - 173s 65ms/step - loss: 0.3160 - accuracy: 0.8587 - val_loss: 0.3170 - val_accuracy: 0.8584
# Epoch 54/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3155 - accuracy: 0.8601 - val_loss: 0.3157 - val_accuracy: 0.8595
# Epoch 55/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3165 - accuracy: 0.8584 - val_loss: 0.3175 - val_accuracy: 0.8580
# Epoch 56/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3151 - accuracy: 0.8596 - val_loss: 0.3157 - val_accuracy: 0.8586
# Epoch 57/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3150 - accuracy: 0.8600 - val_loss: 0.3184 - val_accuracy: 0.8574
# Epoch 58/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3152 - accuracy: 0.8590 - val_loss: 0.3166 - val_accuracy: 0.8595
# Epoch 59/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3148 - accuracy: 0.8600 - val_loss: 0.3151 - val_accuracy: 0.8604
# Epoch 60/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3142 - accuracy: 0.8600 - val_loss: 0.3153 - val_accuracy: 0.8599
# Epoch 61/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3144 - accuracy: 0.8605 - val_loss: 0.3134 - val_accuracy: 0.8610
# Epoch 62/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3134 - accuracy: 0.8606 - val_loss: 0.3142 - val_accuracy: 0.8610
# Epoch 63/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3131 - accuracy: 0.8605 - val_loss: 0.3153 - val_accuracy: 0.8609
# Epoch 64/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3117 - accuracy: 0.8615 - val_loss: 0.3161 - val_accuracy: 0.8584
# Epoch 65/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3123 - accuracy: 0.8605 - val_loss: 0.3136 - val_accuracy: 0.8615
# Epoch 66/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3111 - accuracy: 0.8623 - val_loss: 0.3134 - val_accuracy: 0.8613
# Epoch 67/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3123 - accuracy: 0.8613 - val_loss: 0.3130 - val_accuracy: 0.8617
# Epoch 68/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3123 - accuracy: 0.8612 - val_loss: 0.3137 - val_accuracy: 0.8611
# Epoch 69/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3106 - accuracy: 0.8622 - val_loss: 0.3125 - val_accuracy: 0.8617
# Epoch 70/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3111 - accuracy: 0.8620 - val_loss: 0.3135 - val_accuracy: 0.8621
# Epoch 71/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3120 - accuracy: 0.8615 - val_loss: 0.3122 - val_accuracy: 0.8618
# Epoch 72/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3119 - accuracy: 0.8614 - val_loss: 0.3113 - val_accuracy: 0.8617
# Epoch 73/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3113 - accuracy: 0.8621 - val_loss: 0.3116 - val_accuracy: 0.8615
# Epoch 74/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3092 - accuracy: 0.8633 - val_loss: 0.3136 - val_accuracy: 0.8620
# Epoch 75/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3098 - accuracy: 0.8629 - val_loss: 0.3130 - val_accuracy: 0.8619
# Epoch 76/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3103 - accuracy: 0.8630 - val_loss: 0.3132 - val_accuracy: 0.8613
# Epoch 77/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3119 - accuracy: 0.8620 - val_loss: 0.3118 - val_accuracy: 0.8626
# Epoch 78/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3101 - accuracy: 0.8629 - val_loss: 0.3125 - val_accuracy: 0.8621
# Epoch 79/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3093 - accuracy: 0.8627 - val_loss: 0.3116 - val_accuracy: 0.8625
# Epoch 80/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3070 - accuracy: 0.8637 - val_loss: 0.3115 - val_accuracy: 0.8614
# Epoch 81/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3087 - accuracy: 0.8627 - val_loss: 0.3106 - val_accuracy: 0.8623
# Epoch 82/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3090 - accuracy: 0.8628 - val_loss: 0.3118 - val_accuracy: 0.8619
# Epoch 83/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3087 - accuracy: 0.8640 - val_loss: 0.3100 - val_accuracy: 0.8630
# Epoch 84/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3085 - accuracy: 0.8630 - val_loss: 0.3096 - val_accuracy: 0.8626
# Epoch 85/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3078 - accuracy: 0.8643 - val_loss: 0.3102 - val_accuracy: 0.8623
# Epoch 86/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3064 - accuracy: 0.8649 - val_loss: 0.3106 - val_accuracy: 0.8630
# Epoch 87/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3074 - accuracy: 0.8642 - val_loss: 0.3112 - val_accuracy: 0.8626
# Epoch 88/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3086 - accuracy: 0.8637 - val_loss: 0.3111 - val_accuracy: 0.8628
# Epoch 89/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3064 - accuracy: 0.8649 - val_loss: 0.3113 - val_accuracy: 0.8622
# Epoch 90/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3086 - accuracy: 0.8627 - val_loss: 0.3100 - val_accuracy: 0.8631
# Epoch 91/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3060 - accuracy: 0.8643 - val_loss: 0.3094 - val_accuracy: 0.8629
# Epoch 92/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3077 - accuracy: 0.8645 - val_loss: 0.3092 - val_accuracy: 0.8630
# Epoch 93/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3062 - accuracy: 0.8653 - val_loss: 0.3131 - val_accuracy: 0.8617
# Epoch 94/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3058 - accuracy: 0.8651 - val_loss: 0.3086 - val_accuracy: 0.8637
# Epoch 95/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3072 - accuracy: 0.8645 - val_loss: 0.3096 - val_accuracy: 0.8638
# Epoch 96/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3054 - accuracy: 0.8651 - val_loss: 0.3092 - val_accuracy: 0.8640
# Epoch 97/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3072 - accuracy: 0.8639 - val_loss: 0.3097 - val_accuracy: 0.8634
# Epoch 98/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3055 - accuracy: 0.8649 - val_loss: 0.3101 - val_accuracy: 0.8633
# Epoch 99/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3055 - accuracy: 0.8647 - val_loss: 0.3090 - val_accuracy: 0.8631
# Epoch 100/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3048 - accuracy: 0.8660 - val_loss: 0.3088 - val_accuracy: 0.8640
# Epoch 101/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3053 - accuracy: 0.8657 - val_loss: 0.3076 - val_accuracy: 0.8642
# Epoch 102/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3054 - accuracy: 0.8651 - val_loss: 0.3099 - val_accuracy: 0.8633
# Epoch 103/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3061 - accuracy: 0.8648 - val_loss: 0.3099 - val_accuracy: 0.8622
# Epoch 104/300
# 2635/2635 [==============================] - 174s 66ms/step - loss: 0.3048 - accuracy: 0.8657 - val_loss: 0.3078 - val_accuracy: 0.8643
# Epoch 105/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3044 - accuracy: 0.8658 - val_loss: 0.3078 - val_accuracy: 0.8637
# Epoch 106/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3053 - accuracy: 0.8657 - val_loss: 0.3090 - val_accuracy: 0.8636
# Epoch 107/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3052 - accuracy: 0.8652 - val_loss: 0.3084 - val_accuracy: 0.8639
# Epoch 108/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3045 - accuracy: 0.8655 - val_loss: 0.3086 - val_accuracy: 0.8635
# Epoch 109/300
# 2635/2635 [==============================] - 171s 65ms/step - loss: 0.3056 - accuracy: 0.8652 - val_loss: 0.3068 - val_accuracy: 0.8644
# Epoch 110/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3039 - accuracy: 0.8660 - val_loss: 0.3072 - val_accuracy: 0.8642
# Epoch 111/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3042 - accuracy: 0.8665 - val_loss: 0.3090 - val_accuracy: 0.8628
# Epoch 112/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.3036 - accuracy: 0.8662 - val_loss: 0.3074 - val_accuracy: 0.8643
# Epoch 113/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3031 - accuracy: 0.8667 - val_loss: 0.3073 - val_accuracy: 0.8637
# Epoch 114/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3025 - accuracy: 0.8669 - val_loss: 0.3076 - val_accuracy: 0.8643
# Epoch 115/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.3027 - accuracy: 0.8665 - val_loss: 0.3071 - val_accuracy: 0.8640
# Epoch 116/300
# 2635/2635 [==============================] - 169s 64ms/step - loss: 0.3035 - accuracy: 0.8663 - val_loss: 0.3077 - val_accuracy: 0.8645
# Epoch 117/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3033 - accuracy: 0.8680 - val_loss: 0.3075 - val_accuracy: 0.8646
# Epoch 118/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3025 - accuracy: 0.8671 - val_loss: 0.3072 - val_accuracy: 0.8642
# Epoch 119/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3021 - accuracy: 0.8664 - val_loss: 0.3074 - val_accuracy: 0.8638
# Epoch 120/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.3056 - accuracy: 0.8650 - val_loss: 0.3070 - val_accuracy: 0.8643
# Epoch 121/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3026 - accuracy: 0.8660 - val_loss: 0.3071 - val_accuracy: 0.8654
# Epoch 122/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3029 - accuracy: 0.8668 - val_loss: 0.3062 - val_accuracy: 0.8649
# Epoch 123/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3023 - accuracy: 0.8670 - val_loss: 0.3061 - val_accuracy: 0.8648
# Epoch 124/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3024 - accuracy: 0.8669 - val_loss: 0.3064 - val_accuracy: 0.8650
# Epoch 125/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3028 - accuracy: 0.8662 - val_loss: 0.3068 - val_accuracy: 0.8643
# Epoch 126/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3031 - accuracy: 0.8668 - val_loss: 0.3064 - val_accuracy: 0.8647
# Epoch 127/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3022 - accuracy: 0.8673 - val_loss: 0.3075 - val_accuracy: 0.8646
# Epoch 128/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.3025 - accuracy: 0.8663 - val_loss: 0.3056 - val_accuracy: 0.8653
# Epoch 129/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3022 - accuracy: 0.8674 - val_loss: 0.3067 - val_accuracy: 0.8643
# Epoch 130/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3019 - accuracy: 0.8670 - val_loss: 0.3071 - val_accuracy: 0.8651
# Epoch 131/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3043 - accuracy: 0.8661 - val_loss: 0.3059 - val_accuracy: 0.8650
# Epoch 132/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.3024 - accuracy: 0.8670 - val_loss: 0.3061 - val_accuracy: 0.8647
# Epoch 133/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3017 - accuracy: 0.8677 - val_loss: 0.3067 - val_accuracy: 0.8638
# Epoch 134/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3000 - accuracy: 0.8685 - val_loss: 0.3081 - val_accuracy: 0.8637
# Epoch 135/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3014 - accuracy: 0.8668 - val_loss: 0.3064 - val_accuracy: 0.8645
# Epoch 136/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3006 - accuracy: 0.8678 - val_loss: 0.3056 - val_accuracy: 0.8649
# Epoch 137/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3013 - accuracy: 0.8687 - val_loss: 0.3065 - val_accuracy: 0.8650
# Epoch 138/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3001 - accuracy: 0.8677 - val_loss: 0.3058 - val_accuracy: 0.8642
# Epoch 139/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2999 - accuracy: 0.8683 - val_loss: 0.3055 - val_accuracy: 0.8652
# Epoch 140/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3006 - accuracy: 0.8674 - val_loss: 0.3082 - val_accuracy: 0.8644
# Epoch 141/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3001 - accuracy: 0.8683 - val_loss: 0.3062 - val_accuracy: 0.8656
# Epoch 142/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2992 - accuracy: 0.8679 - val_loss: 0.3069 - val_accuracy: 0.8650
# Epoch 143/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3001 - accuracy: 0.8682 - val_loss: 0.3057 - val_accuracy: 0.8655
# Epoch 144/300
# 2635/2635 [==============================] - 145s 55ms/step - loss: 0.3001 - accuracy: 0.8683 - val_loss: 0.3062 - val_accuracy: 0.8646
# Epoch 145/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3008 - accuracy: 0.8677 - val_loss: 0.3049 - val_accuracy: 0.8658
# Epoch 146/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.3002 - accuracy: 0.8682 - val_loss: 0.3051 - val_accuracy: 0.8653
# Epoch 147/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3002 - accuracy: 0.8679 - val_loss: 0.3064 - val_accuracy: 0.8646
# Epoch 148/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.3007 - accuracy: 0.8677 - val_loss: 0.3056 - val_accuracy: 0.8653
# Epoch 149/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.3012 - accuracy: 0.8683 - val_loss: 0.3044 - val_accuracy: 0.8653
# Epoch 150/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2987 - accuracy: 0.8694 - val_loss: 0.3045 - val_accuracy: 0.8658
# Epoch 151/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3022 - accuracy: 0.8670 - val_loss: 0.3048 - val_accuracy: 0.8660
# Epoch 152/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3005 - accuracy: 0.8681 - val_loss: 0.3051 - val_accuracy: 0.8659
# Epoch 153/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3001 - accuracy: 0.8682 - val_loss: 0.3053 - val_accuracy: 0.8655
# Epoch 154/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2992 - accuracy: 0.8683 - val_loss: 0.3051 - val_accuracy: 0.8656
# Epoch 155/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2983 - accuracy: 0.8693 - val_loss: 0.3049 - val_accuracy: 0.8654
# Epoch 156/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2984 - accuracy: 0.8688 - val_loss: 0.3072 - val_accuracy: 0.8647
# Epoch 157/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2987 - accuracy: 0.8690 - val_loss: 0.3039 - val_accuracy: 0.8662
# Epoch 158/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.3006 - accuracy: 0.8677 - val_loss: 0.3061 - val_accuracy: 0.8652
# Epoch 159/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2993 - accuracy: 0.8682 - val_loss: 0.3055 - val_accuracy: 0.8655
# Epoch 160/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2989 - accuracy: 0.8690 - val_loss: 0.3043 - val_accuracy: 0.8657
# Epoch 161/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2984 - accuracy: 0.8691 - val_loss: 0.3051 - val_accuracy: 0.8649
# Epoch 162/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2982 - accuracy: 0.8691 - val_loss: 0.3046 - val_accuracy: 0.8654
# Epoch 163/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2992 - accuracy: 0.8689 - val_loss: 0.3042 - val_accuracy: 0.8655
# Epoch 164/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2986 - accuracy: 0.8688 - val_loss: 0.3051 - val_accuracy: 0.8656
# Epoch 165/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2988 - accuracy: 0.8693 - val_loss: 0.3038 - val_accuracy: 0.8656
# Epoch 166/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2987 - accuracy: 0.8682 - val_loss: 0.3040 - val_accuracy: 0.8663
# Epoch 167/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2991 - accuracy: 0.8684 - val_loss: 0.3044 - val_accuracy: 0.8648
# Epoch 168/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2977 - accuracy: 0.8700 - val_loss: 0.3053 - val_accuracy: 0.8656
# Epoch 169/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2984 - accuracy: 0.8686 - val_loss: 0.3040 - val_accuracy: 0.8659
# Epoch 170/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2980 - accuracy: 0.8699 - val_loss: 0.3033 - val_accuracy: 0.8663
# Epoch 171/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2973 - accuracy: 0.8696 - val_loss: 0.3059 - val_accuracy: 0.8653
# Epoch 172/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2980 - accuracy: 0.8699 - val_loss: 0.3034 - val_accuracy: 0.8659
# Epoch 173/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2958 - accuracy: 0.8704 - val_loss: 0.3040 - val_accuracy: 0.8663
# Epoch 174/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2990 - accuracy: 0.8692 - val_loss: 0.3044 - val_accuracy: 0.8655
# Epoch 175/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2976 - accuracy: 0.8691 - val_loss: 0.3045 - val_accuracy: 0.8650
# Epoch 176/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2973 - accuracy: 0.8692 - val_loss: 0.3042 - val_accuracy: 0.8656
# Epoch 177/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2952 - accuracy: 0.8711 - val_loss: 0.3036 - val_accuracy: 0.8659
# Epoch 178/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2969 - accuracy: 0.8696 - val_loss: 0.3050 - val_accuracy: 0.8650
# Epoch 179/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2958 - accuracy: 0.8707 - val_loss: 0.3037 - val_accuracy: 0.8657
# Epoch 180/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2964 - accuracy: 0.8693 - val_loss: 0.3047 - val_accuracy: 0.8659
# Epoch 181/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2967 - accuracy: 0.8698 - val_loss: 0.3041 - val_accuracy: 0.8656
# Epoch 182/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2956 - accuracy: 0.8704 - val_loss: 0.3041 - val_accuracy: 0.8658
# Epoch 183/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2961 - accuracy: 0.8704 - val_loss: 0.3045 - val_accuracy: 0.8660
# Epoch 184/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2962 - accuracy: 0.8706 - val_loss: 0.3036 - val_accuracy: 0.8659
# Epoch 185/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2977 - accuracy: 0.8694 - val_loss: 0.3038 - val_accuracy: 0.8657
# Epoch 186/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2957 - accuracy: 0.8707 - val_loss: 0.3048 - val_accuracy: 0.8658
# Epoch 187/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2954 - accuracy: 0.8711 - val_loss: 0.3029 - val_accuracy: 0.8665
# Epoch 188/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2960 - accuracy: 0.8701 - val_loss: 0.3033 - val_accuracy: 0.8663
# Epoch 189/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2960 - accuracy: 0.8701 - val_loss: 0.3070 - val_accuracy: 0.8641
# Epoch 190/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2941 - accuracy: 0.8715 - val_loss: 0.3053 - val_accuracy: 0.8655
# Epoch 191/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2970 - accuracy: 0.8700 - val_loss: 0.3036 - val_accuracy: 0.8658
# Epoch 192/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2955 - accuracy: 0.8704 - val_loss: 0.3028 - val_accuracy: 0.8671
# Epoch 193/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2956 - accuracy: 0.8708 - val_loss: 0.3032 - val_accuracy: 0.8665
# Epoch 194/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2974 - accuracy: 0.8699 - val_loss: 0.3031 - val_accuracy: 0.8662
# Epoch 195/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2958 - accuracy: 0.8703 - val_loss: 0.3027 - val_accuracy: 0.8667
# Epoch 196/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2945 - accuracy: 0.8714 - val_loss: 0.3044 - val_accuracy: 0.8657
# Epoch 197/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2961 - accuracy: 0.8705 - val_loss: 0.3037 - val_accuracy: 0.8658
# Epoch 198/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2966 - accuracy: 0.8693 - val_loss: 0.3035 - val_accuracy: 0.8658
# Epoch 199/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2960 - accuracy: 0.8704 - val_loss: 0.3031 - val_accuracy: 0.8668
# Epoch 200/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2949 - accuracy: 0.8711 - val_loss: 0.3024 - val_accuracy: 0.8668
# Epoch 201/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2951 - accuracy: 0.8703 - val_loss: 0.3026 - val_accuracy: 0.8667
# Epoch 202/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2941 - accuracy: 0.8709 - val_loss: 0.3023 - val_accuracy: 0.8673
# Epoch 203/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2956 - accuracy: 0.8702 - val_loss: 0.3025 - val_accuracy: 0.8668
# Epoch 204/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2955 - accuracy: 0.8700 - val_loss: 0.3028 - val_accuracy: 0.8657
# Epoch 205/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2935 - accuracy: 0.8717 - val_loss: 0.3031 - val_accuracy: 0.8658
# Epoch 206/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2969 - accuracy: 0.8697 - val_loss: 0.3032 - val_accuracy: 0.8661
# Epoch 207/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2948 - accuracy: 0.8715 - val_loss: 0.3028 - val_accuracy: 0.8668
# Epoch 208/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2936 - accuracy: 0.8709 - val_loss: 0.3031 - val_accuracy: 0.8664
# Epoch 209/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2945 - accuracy: 0.8710 - val_loss: 0.3021 - val_accuracy: 0.8665
# Epoch 210/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2958 - accuracy: 0.8703 - val_loss: 0.3025 - val_accuracy: 0.8662
# Epoch 211/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2938 - accuracy: 0.8718 - val_loss: 0.3023 - val_accuracy: 0.8666
# Epoch 212/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2933 - accuracy: 0.8715 - val_loss: 0.3023 - val_accuracy: 0.8664
# Epoch 213/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2958 - accuracy: 0.8704 - val_loss: 0.3029 - val_accuracy: 0.8665
# Epoch 214/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2942 - accuracy: 0.8716 - val_loss: 0.3022 - val_accuracy: 0.8671
# Epoch 215/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2918 - accuracy: 0.8727 - val_loss: 0.3022 - val_accuracy: 0.8675
# Epoch 216/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2944 - accuracy: 0.8709 - val_loss: 0.3025 - val_accuracy: 0.8665
# Epoch 217/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2940 - accuracy: 0.8712 - val_loss: 0.3016 - val_accuracy: 0.8674
# Epoch 218/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2941 - accuracy: 0.8714 - val_loss: 0.3028 - val_accuracy: 0.8664
# Epoch 219/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2922 - accuracy: 0.8721 - val_loss: 0.3025 - val_accuracy: 0.8667
# Epoch 220/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2938 - accuracy: 0.8713 - val_loss: 0.3019 - val_accuracy: 0.8668
# Epoch 221/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2928 - accuracy: 0.8716 - val_loss: 0.3012 - val_accuracy: 0.8671
# Epoch 222/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2936 - accuracy: 0.8718 - val_loss: 0.3016 - val_accuracy: 0.8665
# Epoch 223/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2948 - accuracy: 0.8713 - val_loss: 0.3029 - val_accuracy: 0.8672
# Epoch 224/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2914 - accuracy: 0.8732 - val_loss: 0.3024 - val_accuracy: 0.8672
# Epoch 225/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2938 - accuracy: 0.8716 - val_loss: 0.3023 - val_accuracy: 0.8664
# Epoch 226/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2944 - accuracy: 0.8712 - val_loss: 0.3023 - val_accuracy: 0.8664
# Epoch 227/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2932 - accuracy: 0.8717 - val_loss: 0.3019 - val_accuracy: 0.8674
# Epoch 228/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2938 - accuracy: 0.8716 - val_loss: 0.3027 - val_accuracy: 0.8659
# Epoch 229/300
# 2635/2635 [==============================] - 152s 58ms/step - loss: 0.2928 - accuracy: 0.8720 - val_loss: 0.3018 - val_accuracy: 0.8672
# Epoch 230/300
# 2635/2635 [==============================] - 153s 58ms/step - loss: 0.2938 - accuracy: 0.8721 - val_loss: 0.3024 - val_accuracy: 0.8664
# Epoch 231/300
# 2635/2635 [==============================] - 155s 59ms/step - loss: 0.2932 - accuracy: 0.8716 - val_loss: 0.3010 - val_accuracy: 0.8671
# Epoch 232/300
# 2635/2635 [==============================] - 154s 58ms/step - loss: 0.2925 - accuracy: 0.8719 - val_loss: 0.3013 - val_accuracy: 0.8673
# Epoch 233/300
# 2635/2635 [==============================] - 153s 58ms/step - loss: 0.2918 - accuracy: 0.8719 - val_loss: 0.3014 - val_accuracy: 0.8673
# Epoch 234/300
# 2635/2635 [==============================] - 151s 57ms/step - loss: 0.2938 - accuracy: 0.8716 - val_loss: 0.3017 - val_accuracy: 0.8675
# Epoch 235/300
# 2635/2635 [==============================] - 152s 58ms/step - loss: 0.2943 - accuracy: 0.8713 - val_loss: 0.3031 - val_accuracy: 0.8662
# Epoch 236/300
# 2635/2635 [==============================] - 151s 57ms/step - loss: 0.2951 - accuracy: 0.8710 - val_loss: 0.3023 - val_accuracy: 0.8668
# Epoch 237/300
# 2635/2635 [==============================] - 151s 57ms/step - loss: 0.2931 - accuracy: 0.8724 - val_loss: 0.3017 - val_accuracy: 0.8671
# Epoch 238/300
# 2635/2635 [==============================] - 150s 57ms/step - loss: 0.2923 - accuracy: 0.8726 - val_loss: 0.3028 - val_accuracy: 0.8663
# Epoch 239/300
# 2635/2635 [==============================] - 151s 57ms/step - loss: 0.2929 - accuracy: 0.8724 - val_loss: 0.3021 - val_accuracy: 0.8672
# Epoch 240/300
# 2635/2635 [==============================] - 149s 56ms/step - loss: 0.2925 - accuracy: 0.8726 - val_loss: 0.3016 - val_accuracy: 0.8673
# Epoch 241/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2920 - accuracy: 0.8725 - val_loss: 0.3016 - val_accuracy: 0.8680
# Epoch 242/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2928 - accuracy: 0.8719 - val_loss: 0.3020 - val_accuracy: 0.8668
# Epoch 243/300
# 2635/2635 [==============================] - 149s 57ms/step - loss: 0.2918 - accuracy: 0.8722 - val_loss: 0.3013 - val_accuracy: 0.8670
# Epoch 244/300
# 2635/2635 [==============================] - 151s 57ms/step - loss: 0.2928 - accuracy: 0.8720 - val_loss: 0.3010 - val_accuracy: 0.8673
# Epoch 245/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2922 - accuracy: 0.8726 - val_loss: 0.3006 - val_accuracy: 0.8676
# Epoch 246/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2913 - accuracy: 0.8725 - val_loss: 0.3021 - val_accuracy: 0.8670
# Epoch 247/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2920 - accuracy: 0.8725 - val_loss: 0.3013 - val_accuracy: 0.8673
# Epoch 248/300
# 2635/2635 [==============================] - 149s 56ms/step - loss: 0.2900 - accuracy: 0.8732 - val_loss: 0.3013 - val_accuracy: 0.8675
# Epoch 249/300
# 2635/2635 [==============================] - 152s 58ms/step - loss: 0.2917 - accuracy: 0.8732 - val_loss: 0.3009 - val_accuracy: 0.8673
# Epoch 250/300
# 2635/2635 [==============================] - 150s 57ms/step - loss: 0.2916 - accuracy: 0.8726 - val_loss: 0.3009 - val_accuracy: 0.8676
# Epoch 251/300
# 2635/2635 [==============================] - 153s 58ms/step - loss: 0.2928 - accuracy: 0.8721 - val_loss: 0.3016 - val_accuracy: 0.8668
# Epoch 252/300
# 2635/2635 [==============================] - 149s 56ms/step - loss: 0.2910 - accuracy: 0.8736 - val_loss: 0.3015 - val_accuracy: 0.8675
# Epoch 253/300
# 2635/2635 [==============================] - 149s 57ms/step - loss: 0.2939 - accuracy: 0.8710 - val_loss: 0.3018 - val_accuracy: 0.8672
# Epoch 254/300
# 2635/2635 [==============================] - 160s 61ms/step - loss: 0.2897 - accuracy: 0.8739 - val_loss: 0.3017 - val_accuracy: 0.8674
# Epoch 255/300
# 2635/2635 [==============================] - 155s 59ms/step - loss: 0.2899 - accuracy: 0.8737 - val_loss: 0.3012 - val_accuracy: 0.8681
# Epoch 256/300
# 2635/2635 [==============================] - 149s 57ms/step - loss: 0.2910 - accuracy: 0.8730 - val_loss: 0.3015 - val_accuracy: 0.8671
# Epoch 257/300
# 2635/2635 [==============================] - 153s 58ms/step - loss: 0.2903 - accuracy: 0.8733 - val_loss: 0.3003 - val_accuracy: 0.8680
# Epoch 258/300
# 2635/2635 [==============================] - 155s 59ms/step - loss: 0.2912 - accuracy: 0.8720 - val_loss: 0.3019 - val_accuracy: 0.8671
# Epoch 259/300
# 2635/2635 [==============================] - 158s 60ms/step - loss: 0.2900 - accuracy: 0.8738 - val_loss: 0.3021 - val_accuracy: 0.8675
# Epoch 260/300
# 2635/2635 [==============================] - 161s 61ms/step - loss: 0.2894 - accuracy: 0.8740 - val_loss: 0.3003 - val_accuracy: 0.8686
# Epoch 261/300
# 2635/2635 [==============================] - 168s 64ms/step - loss: 0.2908 - accuracy: 0.8726 - val_loss: 0.3011 - val_accuracy: 0.8678
# Epoch 262/300
# 2635/2635 [==============================] - 169s 64ms/step - loss: 0.2897 - accuracy: 0.8743 - val_loss: 0.3004 - val_accuracy: 0.8677
# Epoch 263/300
# 2635/2635 [==============================] - 173s 66ms/step - loss: 0.2920 - accuracy: 0.8722 - val_loss: 0.3015 - val_accuracy: 0.8674
# Epoch 264/300
# 2635/2635 [==============================] - 172s 65ms/step - loss: 0.2897 - accuracy: 0.8743 - val_loss: 0.3012 - val_accuracy: 0.8671
# Epoch 265/300
# 2635/2635 [==============================] - 319s 121ms/step - loss: 0.2913 - accuracy: 0.8728 - val_loss: 0.3005 - val_accuracy: 0.8682
# Epoch 266/300
# 2635/2635 [==============================] - 424s 161ms/step - loss: 0.2892 - accuracy: 0.8735 - val_loss: 0.3013 - val_accuracy: 0.8674
# Epoch 267/300
# 2635/2635 [==============================] - 310s 118ms/step - loss: 0.2902 - accuracy: 0.8735 - val_loss: 0.3008 - val_accuracy: 0.8678
# Epoch 268/300
# 2635/2635 [==============================] - 576s 219ms/step - loss: 0.2902 - accuracy: 0.8732 - val_loss: 0.3017 - val_accuracy: 0.8673
# Epoch 269/300
# 2635/2635 [==============================] - 754s 286ms/step - loss: 0.2895 - accuracy: 0.8742 - val_loss: 0.3006 - val_accuracy: 0.8689
# Epoch 270/300
# 2635/2635 [==============================] - 486s 185ms/step - loss: 0.2912 - accuracy: 0.8723 - val_loss: 0.3004 - val_accuracy: 0.8685
# Epoch 271/300
# 2635/2635 [==============================] - 532s 202ms/step - loss: 0.2903 - accuracy: 0.8738 - val_loss: 0.3014 - val_accuracy: 0.8673
# Epoch 272/300
# 2635/2635 [==============================] - 696s 264ms/step - loss: 0.2911 - accuracy: 0.8729 - val_loss: 0.3003 - val_accuracy: 0.8678
# Epoch 273/300
# 2635/2635 [==============================] - 585s 222ms/step - loss: 0.2899 - accuracy: 0.8730 - val_loss: 0.3008 - val_accuracy: 0.8680
# Epoch 274/300
# 2635/2635 [==============================] - 696s 264ms/step - loss: 0.2910 - accuracy: 0.8736 - val_loss: 0.3001 - val_accuracy: 0.8684
# Epoch 275/300
# 2635/2635 [==============================] - 696s 264ms/step - loss: 0.2896 - accuracy: 0.8739 - val_loss: 0.3009 - val_accuracy: 0.8675
# Epoch 276/300
# 2635/2635 [==============================] - 670s 254ms/step - loss: 0.2903 - accuracy: 0.8735 - val_loss: 0.3003 - val_accuracy: 0.8682
# Epoch 277/300
# 2635/2635 [==============================] - 676s 257ms/step - loss: 0.2906 - accuracy: 0.8737 - val_loss: 0.3012 - val_accuracy: 0.8672
# Epoch 278/300
# 2635/2635 [==============================] - 480s 182ms/step - loss: 0.2898 - accuracy: 0.8738 - val_loss: 0.2996 - val_accuracy: 0.8685
# Epoch 279/300
# 2635/2635 [==============================] - 410s 155ms/step - loss: 0.2896 - accuracy: 0.8733 - val_loss: 0.3002 - val_accuracy: 0.8681
# Epoch 280/300
# 2635/2635 [==============================] - 325s 123ms/step - loss: 0.2900 - accuracy: 0.8735 - val_loss: 0.3016 - val_accuracy: 0.8676
# Epoch 281/300
# 2635/2635 [==============================] - 161s 61ms/step - loss: 0.2898 - accuracy: 0.8739 - val_loss: 0.3010 - val_accuracy: 0.8671
# Epoch 282/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2877 - accuracy: 0.8749 - val_loss: 0.3009 - val_accuracy: 0.8680
# Epoch 283/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2886 - accuracy: 0.8738 - val_loss: 0.3005 - val_accuracy: 0.8682
# Epoch 284/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2886 - accuracy: 0.8738 - val_loss: 0.3002 - val_accuracy: 0.8681
# Epoch 285/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2898 - accuracy: 0.8736 - val_loss: 0.3006 - val_accuracy: 0.8685
# Epoch 286/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2898 - accuracy: 0.8735 - val_loss: 0.3007 - val_accuracy: 0.8676
# Epoch 287/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2891 - accuracy: 0.8738 - val_loss: 0.3025 - val_accuracy: 0.8669
# Epoch 288/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2881 - accuracy: 0.8747 - val_loss: 0.3007 - val_accuracy: 0.8677
# Epoch 289/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2892 - accuracy: 0.8737 - val_loss: 0.3007 - val_accuracy: 0.8678
# Epoch 290/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2897 - accuracy: 0.8737 - val_loss: 0.3007 - val_accuracy: 0.8686
# Epoch 291/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2899 - accuracy: 0.8732 - val_loss: 0.3001 - val_accuracy: 0.8687
# Epoch 292/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2872 - accuracy: 0.8748 - val_loss: 0.3015 - val_accuracy: 0.8679
# Epoch 293/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2889 - accuracy: 0.8738 - val_loss: 0.3005 - val_accuracy: 0.8679
# Epoch 294/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2887 - accuracy: 0.8744 - val_loss: 0.2995 - val_accuracy: 0.8686
# Epoch 295/300
# 2635/2635 [==============================] - 148s 56ms/step - loss: 0.2872 - accuracy: 0.8743 - val_loss: 0.3000 - val_accuracy: 0.8679
# Epoch 296/300
# 2635/2635 [==============================] - 146s 56ms/step - loss: 0.2874 - accuracy: 0.8750 - val_loss: 0.3012 - val_accuracy: 0.8684
# Epoch 297/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2883 - accuracy: 0.8752 - val_loss: 0.2992 - val_accuracy: 0.8687
# Epoch 298/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2888 - accuracy: 0.8735 - val_loss: 0.3000 - val_accuracy: 0.8682
# Epoch 299/300
# 2635/2635 [==============================] - 147s 56ms/step - loss: 0.2878 - accuracy: 0.8750 - val_loss: 0.2999 - val_accuracy: 0.8680
# Epoch 300/300
# 2635/2635 [==============================] - 146s 55ms/step - loss: 0.2892 - accuracy: 0.8739 - val_loss: 0.2997 - val_accuracy: 0.8684

# %%
plt.figure(figsize=(16,2))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.subplot(1,2,2)
plot_graphs(history, 'loss')

# %% [markdown]
# # eval

# %%
test_loss, test_acc = model_high.evaluate([pep_test, aa_test, en_test, ec_test, e1_test, e2_test], y_test)
print('Test Loss: {}'.format(test_loss))
print('Test Accuracy: {}'.format(test_acc))

# prediction
y_pred = [1 if i>=0.5 else 0 for i in model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])]
print(classification_report(y_test, y_pred))
# AUC
probs = model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])
rf_auc = roc_auc_score(y_test, probs)
print('rf auc : {}'.format(rf_auc))
# plot the roc curve for the model_high
rf_fpr, rf_tpr, _ = roc_curve(y_test, probs)
plt.figure(figsize=(4, 4))
plt.plot(rf_fpr, rf_tpr, marker='.', label='RF AUC = {:.4f}'.format(rf_auc), color='orange')
plt.title('ROC curve')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

cf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix, annot=True, fmt=',.0f')
plt.show()
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
plt.show()
# Out:
# 2782/2782 [==============================] - 74s 26ms/step - loss: 0.2926 - accuracy: 0.8737
# Test Loss: 0.29261040687561035
# Test Accuracy: 0.8736600875854492
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.87     44509
#            1       0.84      0.92      0.88     44489
#
#     accuracy                           0.87     88998
#    macro avg       0.88      0.87      0.87     88998
# weighted avg       0.88      0.87      0.87     88998
#
# rf auc : 0.9492758697289317

# %% [markdown]
# * my : Acc 0.873 AUC 0.949
#
#     * CNN + LSTM : Acc 0.867, AUC 0.943
#     * DeepMSpeptide : Acc 0.854 AUC 0.933
#     * AP3 : Acc 0.83 AUC 0.913
#     * PepFormer : Acc 0.867  AUC 0.941
