# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df_aaindex = pd.read_csv('data/aaindex/df_aaindex19.csv')
print(df_aaindex.shape)
df_aaindex.head(1)
tmp = df_aaindex.drop('Unnamed: 0',axis=1).T
aa2val = dict()
for aa, val in zip(tmp.index, tmp.values):
    aa2val[aa]=val
# Out:
# (19, 21)

# %%
df_detect_peptide_train = pd.read_csv('data/df_detect_peptide_train.csv')
test = pd.read_csv('data/df_detect_peptide_test.csv')
train, val = train_test_split(df_detect_peptide_train, test_size=0.2, random_state=7)

# %%
train.head(1)
# Out:
#                peptide               En               Ec               E1 E2  \
# 210101  R.MDKVHSEAER.L  QQKVLQQRMDKVHSE  KVHSEAERLEARFQD  VLQQRMDKVHSEAER  -
#
#                       protein         PEP  ID
# 210101  sp|Q96M63|CC114_HUMAN  MDKVHSEAER   0

# %%
def get_data_labelEnc(df):
    label_enc = {v:k+1 for k, v in enumerate('ARNDCQEGHILKMFPSTWYV')}
    label_enc['Z']=0
    aa_data = [np.array([seq.count(a) for a in 'ARNDCQEGHILKMFPSTWYV'] + list(np.array([aa2val[aa] for aa in seq]).sum(axis=0)))
               for seq in df.PEP.values]
    pep_data = [[label_enc[aa] for aa in seq] + [0]*(30-len(seq))
               for seq in df.PEP.values]
    en_data = [[label_enc[aa] for aa in seq]
               for seq in df.En.values]
    ec_data = [[label_enc[aa] for aa in seq]
               for seq in df.Ec.values]
    e1_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E1.values]
    e2_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E2.values]
    return np.array(aa_data), np.array(pep_data), np.array(en_data), np.array(ec_data), np.array(e1_data), np.array(e2_data), np.array(df.ID.values)

# %%
aa_train, pep_train, en_train, ec_train, e1_train, e2_train, y_train = get_data_labelEnc(train)
aa_val, pep_val, en_val, ec_val, e1_val, e2_val, y_val = get_data_labelEnc(val)
aa_test, pep_test, en_test, ec_test, e1_test, e2_test, y_test = get_data_labelEnc(test)
print(aa_train.shape, pep_train.shape, en_train.shape, ec_train.shape, e1_train.shape, e2_train.shape, y_train.shape)
print(aa_val.shape, pep_val.shape, en_val.shape, ec_val.shape, e1_val.shape, e2_val.shape, y_val.shape)
print(aa_test.shape, pep_test.shape, en_test.shape, ec_test.shape, e1_test.shape, e2_test.shape, y_test.shape)
# Out:
# (215352, 39) (215352, 30) (215352, 15) (215352, 15) (215352, 15) (215352, 15) (215352,)
# (53838, 39) (53838, 30) (53838, 15) (53838, 15) (53838, 15) (53838, 15) (53838,)
# (67298, 39) (67298, 30) (67298, 15) (67298, 15) (67298, 15) (67298, 15) (67298,)

# %%
viz = pd.concat([train, val, test], axis=0).reset_index(drop=True)
p = viz.loc[viz.ID==1]
n = viz.loc[viz.ID==0]
pl = p.PEP.apply(lambda x: len(x)).values
nl = n.PEP.apply(lambda x: len(x)).values
plt.figure(figsize=(20,5))
sns.kdeplot(pl, shade=True, color='blue')
sns.kdeplot(nl, shade=True, color='red')
plt.legend(['ID', 'nonID'])
plt.show()

# %% [markdown]
# # Train

# %%
from tensorflow.python.client import device_lib

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*4)])
    except RuntimeError as e:
        print(e)

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# # high param

# %%
pep = tf.keras.layers.Input(shape=((30,)))
input1_ = tf.keras.layers.Embedding(21, 32, input_length=30, mask_zero=True)(pep)
input1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input1_)

input2 = tf.keras.layers.Input(shape=((39,)))  # peptide info

n = tf.keras.layers.Input(shape=((15,)))
input3_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(n)
input3 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input3_)

c = tf.keras.layers.Input(shape=((15,)))
input4_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(c)
input4 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input4_)

m1 = tf.keras.layers.Input(shape=((15,)))
input5_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m1)
input5 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input5_)

m2 = tf.keras.layers.Input(shape=((15,)))
input6_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m2)
input6 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input6_)




reshap1 = keras.backend.reshape(input1, [-1, 30, 32, 1])
cnn1 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Conv1D(
        filters=32, kernel_size=2, strides=1, padding='same')
    )(reshap1)
avgpool1 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.AveragePooling1D(pool_size=2)
    )(cnn1)
flat1 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Flatten()
    )(avgpool1)
lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16))(flat1)
net_lstm_ = tf.keras.layers.Dense(16, activation='relu')(lstm1)
net_lstm = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_lstm_)

net_dense1_ = tf.keras.layers.Dense(32, activation='relu')(input2)
net_dense1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_dense1_)

reshap3 = keras.backend.reshape(input3, [-1, 15, 16, 1])
cnn3 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Conv1D(
        filters=16, kernel_size=2, strides=1, padding='same')
    )(reshap3)
avgpool3 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.AveragePooling1D(pool_size=2)
    )(cnn3)
flat3 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Flatten()
    )(avgpool3)
digest_n = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(flat3)
net_n_ = tf.keras.layers.Dense(8, activation='relu')(digest_n)
net_n = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_n_)

reshap4 = keras.backend.reshape(input4, [-1, 15, 16, 1])
cnn4 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Conv1D(
        filters=16, kernel_size=2, strides=1, padding='same')
    )(reshap4)
avgpool4 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.AveragePooling1D(pool_size=2)
    )(cnn4)
flat4 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Flatten()
    )(avgpool4)
digest_c = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(flat4)
net_c_ = tf.keras.layers.Dense(8, activation='relu')(digest_c)
net_c = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_c_)

reshap5 = keras.backend.reshape(input5, [-1, 15, 16, 1])
cnn5 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Conv1D(
        filters=16, kernel_size=2, strides=1, padding='same')
    )(reshap5)
avgpool5 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.AveragePooling1D(pool_size=2)
    )(cnn5)
flat5 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Flatten()
    )(avgpool5)
digest_m1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(flat5)
net_m1_ = tf.keras.layers.Dense(8, activation='relu')(digest_m1)
net_m1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m1_)

reshap6 = keras.backend.reshape(input6, [-1, 15, 16, 1])
cnn6 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Conv1D(
        filters=16, kernel_size=2, strides=1, padding='same')
    )(reshap6)
avgpool6 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.AveragePooling1D(pool_size=2)
    )(cnn6)
flat6 = tf.keras.layers.TimeDistributed(
    tf.keras.layers.Flatten()
    )(avgpool6)
digest_m2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(flat6)
net_m2_ = tf.keras.layers.Dense(8, activation='relu')(digest_m2)
net_m2 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m2_)






cnn1 = tf.keras.layers.Conv1D(filters=16, kernel_size=3, strides=1, padding='same')(input1)
lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16))(cnn1)
net_lstm_ = tf.keras.layers.Dense(16, activation='relu')(lstm1)
net_lstm = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_lstm_)

net_dense1_ = tf.keras.layers.Dense(32, activation='relu')(input2)
net_dense1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_dense1_)

cnn3 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input3)
digest_n = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn3)
net_n_ = tf.keras.layers.Dense(8, activation='relu')(digest_n)
net_n = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_n_)

cnn4 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input4)
digest_c = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn4)
net_c_ = tf.keras.layers.Dense(8, activation='relu')(digest_c)
net_c = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_c_)

cnn5 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input5)
digest_m1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn5)
net_m1_ = tf.keras.layers.Dense(8, activation='relu')(digest_m1)
net_m1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m1_)

cnn6 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input6)
digest_m2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn6)
net_m2_ = tf.keras.layers.Dense(8, activation='relu')(digest_m2)
net_m2 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m2_)








merge = tf.keras.layers.concatenate([net_lstm, 
                                     net_dense1,
                                     net_n,
                                     net_c,
                                     net_m1,
                                     net_m2])

net1 = tf.keras.layers.Dense(64, activation='relu')(merge)
net1_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net1)
net3 = tf.keras.layers.Dense(32, activation='relu')(net1_drop)
net3_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net3)

output = tf.keras.layers.Dense(1, activation = 'sigmoid')(net3_drop)

model_high = tf.keras.Model(inputs=[pep, input2,
                              n, c,
                              m1, m2],
                       outputs=[output])

model_high.summary()

model_high.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      mode='min', 
                                      verbose=1,
                                      patience=50)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 30)]         0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 30, 32)       672         input_25[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 15, 16)       336         input_27[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 15, 16)       336         input_28[0][0]
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 15, 16)       336         input_29[0][0]
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 15, 16)       336         input_30[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 30, 32)       0           embedding_20[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 15, 16)       0           embedding_21[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 15, 16)       0           embedding_22[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 15, 16)       0           embedding_23[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 15, 16)       0           embedding_24[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 30, 16)       1552        dropout_28[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 15, 8)        392         dropout_29[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 15, 8)        392         dropout_30[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 15, 8)        392         dropout_31[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 15, 8)        392         dropout_32[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 32)           4224        conv1d_8[0][0]
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 39)]         0
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 16)           1088        conv1d_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 16)           1088        conv1d_10[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, 16)           1088        conv1d_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_11 (Bidirectional (None, 16)           1088        conv1d_12[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 16)           528         bidirectional_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           1280        input_26[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            136         bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 8)            136         bidirectional_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 8)            136         bidirectional_10[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 8)            136         bidirectional_11[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 16)           0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 32)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 8)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 8)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 8)            0           dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 8)            0           dense_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 80)           0           dropout_33[0][0]
#                                                                  dropout_34[0][0]
#                                                                  dropout_35[0][0]
#                                                                  dropout_36[0][0]
#                                                                  dropout_37[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 64)           5184        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 64)           0           dense_15[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 32)           2080        dropout_39[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 32)           0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1)            33          dropout_40[0][0]
# ==================================================================================================
# Total params: 23,361
# Trainable params: 23,361
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model_high.fit([pep_train, aa_train, en_train, ec_train, e1_train, e2_train],
                    y_train, 
                    epochs=300,
                    batch_size=128,
                    validation_data=([pep_val, aa_val, en_val, ec_val, e1_val, e2_val], y_val),
                    callbacks=[es]
                        )
# Out:
# Epoch 1/300
# 1683/1683 [==============================] - 50s 22ms/step - loss: 7.5551 - accuracy: 0.5105 - val_loss: 0.6885 - val_accuracy: 0.5256
# Epoch 2/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.7766 - accuracy: 0.5292 - val_loss: 0.6754 - val_accuracy: 0.6300
# Epoch 3/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.6730 - accuracy: 0.6112 - val_loss: 0.5125 - val_accuracy: 0.7651
# Epoch 4/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.5526 - accuracy: 0.7360 - val_loss: 0.4745 - val_accuracy: 0.7793
# Epoch 5/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.5062 - accuracy: 0.7663 - val_loss: 0.4515 - val_accuracy: 0.7908
# Epoch 6/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4794 - accuracy: 0.7814 - val_loss: 0.4459 - val_accuracy: 0.7923
# Epoch 7/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4661 - accuracy: 0.7862 - val_loss: 0.4364 - val_accuracy: 0.7956
# Epoch 8/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4551 - accuracy: 0.7909 - val_loss: 0.4432 - val_accuracy: 0.7894
# Epoch 9/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4493 - accuracy: 0.7926 - val_loss: 0.4297 - val_accuracy: 0.8003
# Epoch 10/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4435 - accuracy: 0.7975 - val_loss: 0.4301 - val_accuracy: 0.7991
# Epoch 11/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4396 - accuracy: 0.7988 - val_loss: 0.4302 - val_accuracy: 0.8004
# Epoch 12/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4374 - accuracy: 0.8010 - val_loss: 0.4233 - val_accuracy: 0.8043
# Epoch 13/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4291 - accuracy: 0.8061 - val_loss: 0.4203 - val_accuracy: 0.8073
# Epoch 14/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4279 - accuracy: 0.8061 - val_loss: 0.4149 - val_accuracy: 0.8104
# Epoch 15/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4284 - accuracy: 0.8053 - val_loss: 0.4115 - val_accuracy: 0.8121
# Epoch 16/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4240 - accuracy: 0.8093 - val_loss: 0.4096 - val_accuracy: 0.8134
# Epoch 17/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4219 - accuracy: 0.8108 - val_loss: 0.4114 - val_accuracy: 0.8130
# Epoch 18/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4220 - accuracy: 0.8086 - val_loss: 0.4079 - val_accuracy: 0.8162
# Epoch 19/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4179 - accuracy: 0.8126 - val_loss: 0.4075 - val_accuracy: 0.8163
# Epoch 20/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4158 - accuracy: 0.8121 - val_loss: 0.4034 - val_accuracy: 0.8182
# Epoch 21/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4123 - accuracy: 0.8152 - val_loss: 0.4044 - val_accuracy: 0.8195
# Epoch 22/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4107 - accuracy: 0.8145 - val_loss: 0.4018 - val_accuracy: 0.8202
# Epoch 23/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4094 - accuracy: 0.8161 - val_loss: 0.4025 - val_accuracy: 0.8182
# Epoch 24/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4111 - accuracy: 0.8152 - val_loss: 0.4031 - val_accuracy: 0.8177
# Epoch 25/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4080 - accuracy: 0.8164 - val_loss: 0.4062 - val_accuracy: 0.8177
# Epoch 26/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4064 - accuracy: 0.8176 - val_loss: 0.3979 - val_accuracy: 0.8217
# Epoch 27/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4057 - accuracy: 0.8176 - val_loss: 0.3993 - val_accuracy: 0.8206
# Epoch 28/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4062 - accuracy: 0.8176 - val_loss: 0.3977 - val_accuracy: 0.8225
# Epoch 29/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4043 - accuracy: 0.8190 - val_loss: 0.3968 - val_accuracy: 0.8219
# Epoch 30/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4029 - accuracy: 0.8197 - val_loss: 0.3966 - val_accuracy: 0.8213
# Epoch 31/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4021 - accuracy: 0.8196 - val_loss: 0.3962 - val_accuracy: 0.8229
# Epoch 32/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.4033 - accuracy: 0.8201 - val_loss: 0.3943 - val_accuracy: 0.8233
# Epoch 33/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.4024 - accuracy: 0.8193 - val_loss: 0.3933 - val_accuracy: 0.8241
# Epoch 34/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3990 - accuracy: 0.8217 - val_loss: 0.3947 - val_accuracy: 0.8233
# Epoch 35/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3989 - accuracy: 0.8213 - val_loss: 0.3937 - val_accuracy: 0.8234
# Epoch 36/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3987 - accuracy: 0.8215 - val_loss: 0.3941 - val_accuracy: 0.8243
# Epoch 37/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3992 - accuracy: 0.8209 - val_loss: 0.3926 - val_accuracy: 0.8250
# Epoch 38/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3983 - accuracy: 0.8221 - val_loss: 0.3926 - val_accuracy: 0.8238
# Epoch 39/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3976 - accuracy: 0.8221 - val_loss: 0.3909 - val_accuracy: 0.8258
# Epoch 40/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.
300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3624 - accuracy: 0.8389 - val_loss: 0.3652 - val_accuracy: 0.8388
# Epoch 231/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3593 - accuracy: 0.8398 - val_loss: 0.3667 - val_accuracy: 0.8392
# Epoch 232/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3596 - accuracy: 0.8404 - val_loss: 0.3649 - val_accuracy: 0.8390
# Epoch 233/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3591 - accuracy: 0.8415 - val_loss: 0.3655 - val_accuracy: 0.8383
# Epoch 234/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3588 - accuracy: 0.8414 - val_loss: 0.3682 - val_accuracy: 0.8369
# Epoch 235/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3579 - accuracy: 0.8405 - val_loss: 0.3674 - val_accuracy: 0.8368
# Epoch 236/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3580 - accuracy: 0.8412 - val_loss: 0.3652 - val_accuracy: 0.8388
# Epoch 237/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3563 - accuracy: 0.8417 - val_loss: 0.3675 - val_accuracy: 0.8381
# Epoch 238/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3590 - accuracy: 0.8407 - val_loss: 0.3664 - val_accuracy: 0.8381
# Epoch 239/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3589 - accuracy: 0.8408 - val_loss: 0.3701 - val_accuracy: 0.8362
# Epoch 240/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3576 - accuracy: 0.8417 - val_loss: 0.3649 - val_accuracy: 0.8394
# Epoch 241/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3590 - accuracy: 0.8407 - val_loss: 0.3653 - val_accuracy: 0.8393
# Epoch 242/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3576 - accuracy: 0.8413 - val_loss: 0.3669 - val_accuracy: 0.8384
# Epoch 243/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3579 - accuracy: 0.8411 - val_loss: 0.3660 - val_accuracy: 0.8380
# Epoch 244/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3548 - accuracy: 0.8437 - val_loss: 0.3647 - val_accuracy: 0.8390
# Epoch 245/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3578 - accuracy: 0.8411 - val_loss: 0.3651 - val_accuracy: 0.8384
# Epoch 246/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3576 - accuracy: 0.8424 - val_loss: 0.3645 - val_accuracy: 0.8393
# Epoch 247/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3568 - accuracy: 0.8421 - val_loss: 0.3654 - val_accuracy: 0.8391
# Epoch 248/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3585 - accuracy: 0.8409 - val_loss: 0.3647 - val_accuracy: 0.8394
# Epoch 249/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3569 - accuracy: 0.8426 - val_loss: 0.3675 - val_accuracy: 0.8378
# Epoch 250/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3584 - accuracy: 0.8417 - val_loss: 0.3657 - val_accuracy: 0.8385
# Epoch 251/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3569 - accuracy: 0.8409 - val_loss: 0.3662 - val_accuracy: 0.8388
# Epoch 252/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3597 - accuracy: 0.8402 - val_loss: 0.3657 - val_accuracy: 0.8388
# Epoch 253/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3573 - accuracy: 0.8418 - val_loss: 0.3652 - val_accuracy: 0.8387
# Epoch 254/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3586 - accuracy: 0.8406 - val_loss: 0.3652 - val_accuracy: 0.8378
# Epoch 255/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3568 - accuracy: 0.8419 - val_loss: 0.3651 - val_accuracy: 0.8387
# Epoch 256/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3584 - accuracy: 0.8406 - val_loss: 0.3653 - val_accuracy: 0.8388
# Epoch 257/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3560 - accuracy: 0.8415 - val_loss: 0.3654 - val_accuracy: 0.8387
# Epoch 258/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3568 - accuracy: 0.8422 - val_loss: 0.3649 - val_accuracy: 0.8385
# Epoch 259/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3548 - accuracy: 0.8424 - val_loss: 0.3644 - val_accuracy: 0.8389
# Epoch 260/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3551 - accuracy: 0.8443 - val_loss: 0.3662 - val_accuracy: 0.8380
# Epoch 261/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3569 - accuracy: 0.8424 - val_loss: 0.3651 - val_accuracy: 0.8395
# Epoch 262/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3577 - accuracy: 0.8417 - val_loss: 0.3642 - val_accuracy: 0.8391
# Epoch 263/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3566 - accuracy: 0.8431 - val_loss: 0.3653 - val_accuracy: 0.8393
# Epoch 264/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3560 - accuracy: 0.8426 - val_loss: 0.3661 - val_accuracy: 0.8378
# Epoch 265/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3554 - accuracy: 0.8428 - val_loss: 0.3663 - val_accuracy: 0.8381
# Epoch 266/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3569 - accuracy: 0.8419 - val_loss: 0.3648 - val_accuracy: 0.8388
# Epoch 267/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3551 - accuracy: 0.8435 - val_loss: 0.3652 - val_accuracy: 0.8387
# Epoch 268/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3594 - accuracy: 0.8410 - val_loss: 0.3640 - val_accuracy: 0.8385
# Epoch 269/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3555 - accuracy: 0.8429 - val_loss: 0.3652 - val_accuracy: 0.8390
# Epoch 270/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3561 - accuracy: 0.8427 - val_loss: 0.3649 - val_accuracy: 0.8388
# Epoch 271/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3567 - accuracy: 0.8428 - val_loss: 0.3652 - val_accuracy: 0.8389
# Epoch 272/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3550 - accuracy: 0.8433 - val_loss: 0.3639 - val_accuracy: 0.8383
# Epoch 273/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3557 - accuracy: 0.8423 - val_loss: 0.3644 - val_accuracy: 0.8386
# Epoch 274/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3546 - accuracy: 0.8427 - val_loss: 0.3662 - val_accuracy: 0.8380
# Epoch 275/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3557 - accuracy: 0.8429 - val_loss: 0.3660 - val_accuracy: 0.8386
# Epoch 276/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3548 - accuracy: 0.8426 - val_loss: 0.3657 - val_accuracy: 0.8386
# Epoch 277/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3552 - accuracy: 0.8439 - val_loss: 0.3650 - val_accuracy: 0.8386
# Epoch 278/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3564 - accuracy: 0.8433 - val_loss: 0.3648 - val_accuracy: 0.8386
# Epoch 279/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3548 - accuracy: 0.8431 - val_loss: 0.3639 - val_accuracy: 0.8389
# Epoch 280/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3559 - accuracy: 0.8425 - val_loss: 0.3655 - val_accuracy: 0.8381
# Epoch 281/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3562 - accuracy: 0.8428 - val_loss: 0.3664 - val_accuracy: 0.8393
# Epoch 282/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3539 - accuracy: 0.8447 - val_loss: 0.3649 - val_accuracy: 0.8394
# Epoch 283/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3571 - accuracy: 0.8420 - val_loss: 0.3667 - val_accuracy: 0.8386
# Epoch 284/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3551 - accuracy: 0.8427 - val_loss: 0.3663 - val_accuracy: 0.8383
# Epoch 285/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3548 - accuracy: 0.8430 - val_loss: 0.3666 - val_accuracy: 0.8378
# Epoch 286/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3553 - accuracy: 0.8430 - val_loss: 0.3646 - val_accuracy: 0.8395
# Epoch 287/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3550 - accuracy: 0.8432 - val_loss: 0.3658 - val_accuracy: 0.8386
# Epoch 288/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3530 - accuracy: 0.8448 - val_loss: 0.3651 - val_accuracy: 0.8383
# Epoch 289/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3531 - accuracy: 0.8433 - val_loss: 0.3646 - val_accuracy: 0.8396
# Epoch 290/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3559 - accuracy: 0.8417 - val_loss: 0.3648 - val_accuracy: 0.8386
# Epoch 291/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3567 - accuracy: 0.8416 - val_loss: 0.3646 - val_accuracy: 0.8391
# Epoch 292/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3534 - accuracy: 0.8435 - val_loss: 0.3645 - val_accuracy: 0.8394
# Epoch 293/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3547 - accuracy: 0.8443 - val_loss: 0.3653 - val_accuracy: 0.8377
# Epoch 294/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3529 - accuracy: 0.8452 - val_loss: 0.3662 - val_accuracy: 0.8386
# Epoch 295/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3562 - accuracy: 0.8423 - val_loss: 0.3633 - val_accuracy: 0.8396
# Epoch 296/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3567 - accuracy: 0.8421 - val_loss: 0.3642 - val_accuracy: 0.8395
# Epoch 297/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3545 - accuracy: 0.8432 - val_loss: 0.3645 - val_accuracy: 0.8391
# Epoch 298/300
# 1683/1683 [==============================] - 34s 20ms/step - loss: 0.3567 - accuracy: 0.8421 - val_loss: 0.3643 - val_accuracy: 0.8384
# Epoch 299/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3539 - accuracy: 0.8430 - val_loss: 0.3641 - val_accuracy: 0.8377
# Epoch 300/300
# 1683/1683 [==============================] - 33s 20ms/step - loss: 0.3545 - accuracy: 0.8424 - val_loss: 0.3637 - val_accuracy: 0.8386

# %%
plt.figure(figsize=(16,2))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.subplot(1,2,2)
plot_graphs(history, 'loss')

# %% [markdown]
# # eval

# %%
test_loss, test_acc = model_high.evaluate([pep_test, aa_test, en_test, ec_test, e1_test, e2_test], y_test)
print('Test Loss: {}'.format(test_loss))
print('Test Accuracy: {}'.format(test_acc))

# prediction
y_pred = [1 if i>=0.5 else 0 for i in model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])]
print(classification_report(y_test, y_pred))
# AUC
probs = model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])
rf_auc = roc_auc_score(y_test, probs)
print('rf auc : {}'.format(rf_auc))
# plot the roc curve for the model_high
rf_fpr, rf_tpr, _ = roc_curve(y_test, probs)
plt.figure(figsize=(4, 4))
plt.plot(rf_fpr, rf_tpr, marker='.', label='RF AUC = {:.4f}'.format(rf_auc), color='orange')
plt.title('ROC curve')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

cf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix, annot=True, fmt=',.0f')
plt.show()
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
plt.show()
# Out:
# 2104/2104 [==============================] - 15s 7ms/step - loss: 0.3609 - accuracy: 0.8373
# Test Loss: 0.3608633279800415
# Test Accuracy: 0.8372611403465271
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84     33706
#            1       0.83      0.84      0.84     33592
#
#     accuracy                           0.84     67298
#    macro avg       0.84      0.84      0.84     67298
# weighted avg       0.84      0.84      0.84     67298
#
# rf auc : 0.9189278015040244

# %% [markdown]
# # digestibility Embedding Go!
#   - using pre trained protein language model

# %%
Orbitrap
- HCD
iTRAQ-4 Phospho	

Orbitrap -
HCD
Phospho	

Orbitrap -
HCD
TMT-10	

Human, Yeast, Mouse 
https://chemdata.nist.gov/dokuwiki/doku.php?id=peptidew:lib:mouse20130520
https://chemdata.nist.gov/dokuwiki/doku.php?id=peptidew:lib:yeast_it
            
https://chemdata.nist.gov/
https://chemdata.nist.gov/dokuwiki/doku.php?id=peptidew:start
https://chemdata.nist.gov/dokuwiki/doku.php?id=peptidew:cdownload
