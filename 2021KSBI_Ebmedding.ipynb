# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df_aaindex = pd.read_csv('data/aaindex/df_aaindex19.csv')
print(df_aaindex.shape)
df_aaindex.head(1)
tmp = df_aaindex.drop('Unnamed: 0',axis=1).T
aa2val = dict()
for aa, val in zip(tmp.index, tmp.values):
    aa2val[aa]=val
# Out:
# (19, 21)

# %%
df_detect_peptide_train = pd.read_csv('data/df_detect_peptide_train.csv')
test = pd.read_csv('data/df_detect_peptide_test.csv')
train, val = train_test_split(df_detect_peptide_train, test_size=0.2, random_state=7)

# %%
train.head(1)
# Out:
#                peptide               En               Ec               E1 E2  \
# 210101  R.MDKVHSEAER.L  QQKVLQQRMDKVHSE  KVHSEAERLEARFQD  VLQQRMDKVHSEAER  -
#
#                       protein         PEP  ID
# 210101  sp|Q96M63|CC114_HUMAN  MDKVHSEAER   0

# %%
def get_data_labelEnc(df):
    label_enc = {v:k+1 for k, v in enumerate('ARNDCQEGHILKMFPSTWYV')}
    label_enc['Z']=0
    aa_data = [np.array([seq.count(a) for a in 'ARNDCQEGHILKMFPSTWYV'] + list(np.array([aa2val[aa] for aa in seq]).sum(axis=0)))
               for seq in df.PEP.values]
    pep_data = [[label_enc[aa] for aa in seq] + [0]*(30-len(seq))
               for seq in df.PEP.values]
    en_data = [[label_enc[aa] for aa in seq]
               for seq in df.En.values]
    ec_data = [[label_enc[aa] for aa in seq]
               for seq in df.Ec.values]
    e1_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E1.values]
    e2_data = [[label_enc[aa] for aa in seq]
               if seq != '-' else [0 for _ in range(15)]
               for seq in df.E2.values]
    return np.array(aa_data), np.array(pep_data), np.array(en_data), np.array(ec_data), np.array(e1_data), np.array(e2_data), np.array(df.ID.values)

# %%
aa_train, pep_train, en_train, ec_train, e1_train, e2_train, y_train = get_data_labelEnc(train)
aa_val, pep_val, en_val, ec_val, e1_val, e2_val, y_val = get_data_labelEnc(val)
aa_test, pep_test, en_test, ec_test, e1_test, e2_test, y_test = get_data_labelEnc(test)
print(aa_train.shape, pep_train.shape, en_train.shape, ec_train.shape, e1_train.shape, e2_train.shape, y_train.shape)
print(aa_val.shape, pep_val.shape, en_val.shape, ec_val.shape, e1_val.shape, e2_val.shape, y_val.shape)
print(aa_test.shape, pep_test.shape, en_test.shape, ec_test.shape, e1_test.shape, e2_test.shape, y_test.shape)
# Out:
# (215352, 39) (215352, 30) (215352, 15) (215352, 15) (215352, 15) (215352, 15) (215352,)
# (53838, 39) (53838, 30) (53838, 15) (53838, 15) (53838, 15) (53838, 15) (53838,)
# (67298, 39) (67298, 30) (67298, 15) (67298, 15) (67298, 15) (67298, 15) (67298,)

# %% [markdown]
# # Train

# %%
from tensorflow.python.client import device_lib

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024*4)])
    except RuntimeError as e:
        print(e)

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend([metric, 'val_'+metric])

# %% [markdown]
# # high param

# %%
pep = tf.keras.layers.Input(shape=((30,)))
input1_ = tf.keras.layers.Embedding(21, 32, input_length=30, mask_zero=True)(pep)
input1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input1_)

input2 = tf.keras.layers.Input(shape=((39,)))  # peptide info

n = tf.keras.layers.Input(shape=((15,)))
input3_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(n)
input3 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input3_)

c = tf.keras.layers.Input(shape=((15,)))
input4_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(c)
input4 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input4_)

m1 = tf.keras.layers.Input(shape=((15,)))
input5_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m1)
input5 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input5_)

m2 = tf.keras.layers.Input(shape=((15,)))
input6_ = tf.keras.layers.Embedding(21, 16, input_length=15, mask_zero=True)(m2)
input6 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(input6_)







cnn1 = tf.keras.layers.Conv1D(filters=16, kernel_size=3, strides=1, padding='same')(input1)
lstm1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16))(cnn1)
net_lstm_ = tf.keras.layers.Dense(16, activation='relu')(lstm1)
net_lstm = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_lstm_)

net_dense1_ = tf.keras.layers.Dense(32, activation='relu')(input2)
net_dense1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_dense1_)

cnn3 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input3)
digest_n = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn3)
net_n_ = tf.keras.layers.Dense(8, activation='relu')(digest_n)
net_n = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_n_)

cnn4 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input4)
digest_c = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn4)
net_c_ = tf.keras.layers.Dense(8, activation='relu')(digest_c)
net_c = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_c_)

cnn5 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input5)
digest_m1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn5)
net_m1_ = tf.keras.layers.Dense(8, activation='relu')(digest_m1)
net_m1 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m1_)

cnn6 = tf.keras.layers.Conv1D(filters=8, kernel_size=3, strides=1, padding='same')(input6)
digest_m2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8))(cnn6)
net_m2_ = tf.keras.layers.Dense(8, activation='relu')(digest_m2)
net_m2 = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net_m2_)








merge = tf.keras.layers.concatenate([net_lstm, 
                                     net_dense1,
                                     net_n,
                                     net_c,
                                     net_m1,
                                     net_m2])

net1 = tf.keras.layers.Dense(64, activation='relu')(merge)
net1_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net1)
net3 = tf.keras.layers.Dense(32, activation='relu')(net1_drop)
net3_drop = tf.keras.layers.Dropout(np.random.uniform(0, 0.2))(net3)

output = tf.keras.layers.Dense(1, activation = 'sigmoid')(net3_drop)

model_high = tf.keras.Model(inputs=[pep, input2,
                              n, c,
                              m1, m2],
                       outputs=[output])

model_high.summary()

model_high.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                      mode='min', 
                                      verbose=1,
                                      patience=50)
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_91 (InputLayer)           [(None, 30)]         0
# __________________________________________________________________________________________________
# input_93 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_94 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_95 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# input_96 (InputLayer)           [(None, 15)]         0
# __________________________________________________________________________________________________
# embedding_75 (Embedding)        (None, 30, 32)       672         input_91[0][0]
# __________________________________________________________________________________________________
# embedding_76 (Embedding)        (None, 15, 16)       336         input_93[0][0]
# __________________________________________________________________________________________________
# embedding_77 (Embedding)        (None, 15, 16)       336         input_94[0][0]
# __________________________________________________________________________________________________
# embedding_78 (Embedding)        (None, 15, 16)       336         input_95[0][0]
# __________________________________________________________________________________________________
# embedding_79 (Embedding)        (None, 15, 16)       336         input_96[0][0]
# __________________________________________________________________________________________________
# dropout_174 (Dropout)           (None, 30, 32)       0           embedding_75[0][0]
# __________________________________________________________________________________________________
# dropout_175 (Dropout)           (None, 15, 16)       0           embedding_76[0][0]
# __________________________________________________________________________________________________
# dropout_176 (Dropout)           (None, 15, 16)       0           embedding_77[0][0]
# __________________________________________________________________________________________________
# dropout_177 (Dropout)           (None, 15, 16)       0           embedding_78[0][0]
# __________________________________________________________________________________________________
# dropout_178 (Dropout)           (None, 15, 16)       0           embedding_79[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 30, 16)       1552        dropout_174[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 15, 8)        392         dropout_175[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 15, 8)        392         dropout_176[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 15, 8)        392         dropout_177[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 15, 8)        392         dropout_178[0][0]
# __________________________________________________________________________________________________
# bidirectional_75 (Bidirectional (None, 32)           4224        conv1d_50[0][0]
# __________________________________________________________________________________________________
# input_92 (InputLayer)           [(None, 39)]         0
# __________________________________________________________________________________________________
# bidirectional_76 (Bidirectional (None, 16)           1088        conv1d_51[0][0]
# __________________________________________________________________________________________________
# bidirectional_77 (Bidirectional (None, 16)           1088        conv1d_52[0][0]
# __________________________________________________________________________________________________
# bidirectional_78 (Bidirectional (None, 16)           1088        conv1d_53[0][0]
# __________________________________________________________________________________________________
# bidirectional_79 (Bidirectional (None, 16)           1088        conv1d_54[0][0]
# __________________________________________________________________________________________________
# dense_135 (Dense)               (None, 16)           528         bidirectional_75[0][0]
# __________________________________________________________________________________________________
# dense_136 (Dense)               (None, 32)           1280        input_92[0][0]
# __________________________________________________________________________________________________
# dense_137 (Dense)               (None, 8)            136         bidirectional_76[0][0]
# __________________________________________________________________________________________________
# dense_138 (Dense)               (None, 8)            136         bidirectional_77[0][0]
# __________________________________________________________________________________________________
# dense_139 (Dense)               (None, 8)            136         bidirectional_78[0][0]
# __________________________________________________________________________________________________
# dense_140 (Dense)               (None, 8)            136         bidirectional_79[0][0]
# __________________________________________________________________________________________________
# dropout_179 (Dropout)           (None, 16)           0           dense_135[0][0]
# __________________________________________________________________________________________________
# dropout_180 (Dropout)           (None, 32)           0           dense_136[0][0]
# __________________________________________________________________________________________________
# dropout_181 (Dropout)           (None, 8)            0           dense_137[0][0]
# __________________________________________________________________________________________________
# dropout_182 (Dropout)           (None, 8)            0           dense_138[0][0]
# __________________________________________________________________________________________________
# dropout_183 (Dropout)           (None, 8)            0           dense_139[0][0]
# __________________________________________________________________________________________________
# dropout_184 (Dropout)           (None, 8)            0           dense_140[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 80)           0           dropout_179[0][0]
#                                                                  dropout_180[0][0]
#                                                                  dropout_181[0][0]
#                                                                  dropout_182[0][0]
#                                                                  dropout_183[0][0]
#                                                                  dropout_184[0][0]
# __________________________________________________________________________________________________
# dense_141 (Dense)               (None, 64)           5184        concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_185 (Dropout)           (None, 64)           0           dense_141[0][0]
# __________________________________________________________________________________________________
# dense_142 (Dense)               (None, 32)           2080        dropout_185[0][0]
# __________________________________________________________________________________________________
# dropout_186 (Dropout)           (None, 32)           0           dense_142[0][0]
# __________________________________________________________________________________________________
# dense_143 (Dense)               (None, 1)            33          dropout_186[0][0]
# ==================================================================================================
# Total params: 23,361
# Trainable params: 23,361
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model_high.fit([pep_train, aa_train, en_train, ec_train, e1_train, e2_train],
                    y_train, 
                    epochs=300,
                    batch_size=128,
                    validation_data=([pep_val, aa_val, en_val, ec_val, e1_val, e2_val], y_val),
                    callbacks=[es]
                        )
# Out:
# Epoch 1/300
# 1683/1683 [==============================] - 107s 56ms/step - loss: 12.2367 - accuracy: 0.5161 - val_loss: 0.5957 - val_accuracy: 0.7027
# Epoch 2/300
# 1683/1683 [==============================] - 91s 54ms/step - loss: 1.3056 - accuracy: 0.5895 - val_loss: 0.5651 - val_accuracy: 0.7453
# Epoch 3/300
# 1683/1683 [==============================] - 91s 54ms/step - loss: 0.6922 - accuracy: 0.6710 - val_loss: 0.5404 - val_accuracy: 0.7589
# Epoch 4/300
# 1683/1683 [==============================] - 91s 54ms/step - loss: 0.5697 - accuracy: 0.7236 - val_loss: 0.5109 - val_accuracy: 0.7661
# Epoch 5/300
# 1683/1683 [==============================] - 91s 54ms/step - loss: 0.5220 - accuracy: 0.7505 - val_loss: 0.4863 - val_accuracy: 0.7740
# Epoch 6/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.4948 - accuracy: 0.7667 - val_loss: 0.4682 - val_accuracy: 0.7804
# Epoch 7/300
# 1683/1683 [==============================] - 85s 51ms/step - loss: 0.4789 - accuracy: 0.7763 - val_loss: 0.4569 - val_accuracy: 0.7891
# Epoch 8/300
# 1683/1683 [==============================] - 88s 52ms/step - loss: 0.4678 - accuracy: 0.7829 - val_loss: 0.4511 - val_accuracy: 0.7914
# Epoch 9/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.4595 - accuracy: 0.7876 - val_loss: 0.4491 - val_accuracy: 0.7929
# Epoch 10/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.4532 - accuracy: 0.7901 - val_loss: 0.4418 - val_accuracy: 0.7954
# Epoch 11/300
# 1683/1683 [==============================] - 83s 49ms/step - loss: 0.4505 - accuracy: 0.7925 - val_loss: 0.4401 - val_accuracy: 0.8000
# Epoch 12/300
# 1683/1683 [==============================] - 88s 52ms/step - loss: 0.4463 - accuracy: 0.7945 - val_loss: 0.4328 - val_accuracy: 0.8009
# Epoch 13/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.4438 - accuracy: 0.7972 - val_loss: 0.4298 - val_accuracy: 0.8039
# Epoch 14/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.
300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3702 - accuracy: 0.8349 - val_loss: 0.3745 - val_accuracy: 0.8343
# Epoch 137/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3701 - accuracy: 0.8357 - val_loss: 0.3742 - val_accuracy: 0.8344
# Epoch 138/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3696 - accuracy: 0.8355 - val_loss: 0.3725 - val_accuracy: 0.8350
# Epoch 139/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3718 - accuracy: 0.8336 - val_loss: 0.3764 - val_accuracy: 0.8330
# Epoch 140/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3705 - accuracy: 0.8360 - val_loss: 0.3744 - val_accuracy: 0.8349
# Epoch 141/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3686 - accuracy: 0.8366 - val_loss: 0.3729 - val_accuracy: 0.8360
# Epoch 142/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3699 - accuracy: 0.8355 - val_loss: 0.3719 - val_accuracy: 0.8356
# Epoch 143/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3690 - accuracy: 0.8354 - val_loss: 0.3728 - val_accuracy: 0.8358
# Epoch 144/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3678 - accuracy: 0.8358 - val_loss: 0.3745 - val_accuracy: 0.8352
# Epoch 145/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3677 - accuracy: 0.8371 - val_loss: 0.3731 - val_accuracy: 0.8353
# Epoch 146/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3693 - accuracy: 0.8355 - val_loss: 0.3736 - val_accuracy: 0.8352
# Epoch 147/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3701 - accuracy: 0.8363 - val_loss: 0.3739 - val_accuracy: 0.8345
# Epoch 148/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3693 - accuracy: 0.8355 - val_loss: 0.3754 - val_accuracy: 0.8343
# Epoch 149/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3696 - accuracy: 0.8356 - val_loss: 0.3753 - val_accuracy: 0.8339
# Epoch 150/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3697 - accuracy: 0.8352 - val_loss: 0.3734 - val_accuracy: 0.8346
# Epoch 151/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3704 - accuracy: 0.8355 - val_loss: 0.3730 - val_accuracy: 0.8349
# Epoch 152/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3680 - accuracy: 0.8349 - val_loss: 0.3750 - val_accuracy: 0.8352
# Epoch 153/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3682 - accuracy: 0.8368 - val_loss: 0.3781 - val_accuracy: 0.8344
# Epoch 154/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3666 - accuracy: 0.8378 - val_loss: 0.3742 - val_accuracy: 0.8356
# Epoch 155/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3660 - accuracy: 0.8381 - val_loss: 0.3745 - val_accuracy: 0.8343
# Epoch 156/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3680 - accuracy: 0.8373 - val_loss: 0.3730 - val_accuracy: 0.8350
# Epoch 157/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3681 - accuracy: 0.8360 - val_loss: 0.3731 - val_accuracy: 0.8351
# Epoch 158/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3669 - accuracy: 0.8380 - val_loss: 0.3733 - val_accuracy: 0.8351
# Epoch 159/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3677 - accuracy: 0.8375 - val_loss: 0.3753 - val_accuracy: 0.8340
# Epoch 160/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3670 - accuracy: 0.8372 - val_loss: 0.3723 - val_accuracy: 0.8350
# Epoch 161/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3668 - accuracy: 0.8371 - val_loss: 0.3742 - val_accuracy: 0.8357
# Epoch 162/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3650 - accuracy: 0.8382 - val_loss: 0.3743 - val_accuracy: 0.8362
# Epoch 163/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3666 - accuracy: 0.8370 - val_loss: 0.3733 - val_accuracy: 0.8349
# Epoch 164/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3658 - accuracy: 0.8381 - val_loss: 0.3736 - val_accuracy: 0.8348
# Epoch 165/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3660 - accuracy: 0.8369 - val_loss: 0.3732 - val_accuracy: 0.8351
# Epoch 166/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3666 - accuracy: 0.8367 - val_loss: 0.3720 - val_accuracy: 0.8353
# Epoch 167/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3652 - accuracy: 0.8386 - val_loss: 0.3728 - val_accuracy: 0.8347
# Epoch 168/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3653 - accuracy: 0.8382 - val_loss: 0.3715 - val_accuracy: 0.8359
# Epoch 169/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3665 - accuracy: 0.8371 - val_loss: 0.3725 - val_accuracy: 0.8345
# Epoch 170/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3660 - accuracy: 0.8384 - val_loss: 0.3748 - val_accuracy: 0.8335
# Epoch 171/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3659 - accuracy: 0.8385 - val_loss: 0.3713 - val_accuracy: 0.8354
# Epoch 172/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3651 - accuracy: 0.8377 - val_loss: 0.3713 - val_accuracy: 0.8362
# Epoch 173/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3652 - accuracy: 0.8377 - val_loss: 0.3718 - val_accuracy: 0.8359
# Epoch 174/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3668 - accuracy: 0.8376 - val_loss: 0.3747 - val_accuracy: 0.8355
# Epoch 175/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3679 - accuracy: 0.8355 - val_loss: 0.3722 - val_accuracy: 0.8352
# Epoch 176/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3659 - accuracy: 0.8386 - val_loss: 0.3717 - val_accuracy: 0.8354
# Epoch 177/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3655 - accuracy: 0.8384 - val_loss: 0.3716 - val_accuracy: 0.8354
# Epoch 178/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3656 - accuracy: 0.8376 - val_loss: 0.3748 - val_accuracy: 0.8347
# Epoch 179/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3668 - accuracy: 0.8355 - val_loss: 0.3718 - val_accuracy: 0.8359
# Epoch 180/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3655 - accuracy: 0.8380 - val_loss: 0.3736 - val_accuracy: 0.8357
# Epoch 181/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3654 - accuracy: 0.8371 - val_loss: 0.3709 - val_accuracy: 0.8358
# Epoch 182/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3622 - accuracy: 0.8393 - val_loss: 0.3746 - val_accuracy: 0.8343
# Epoch 183/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3655 - accuracy: 0.8372 - val_loss: 0.3718 - val_accuracy: 0.8365
# Epoch 184/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3661 - accuracy: 0.8372 - val_loss: 0.3721 - val_accuracy: 0.8358
# Epoch 185/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3636 - accuracy: 0.8389 - val_loss: 0.3720 - val_accuracy: 0.8354
# Epoch 186/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3663 - accuracy: 0.8370 - val_loss: 0.3710 - val_accuracy: 0.8356
# Epoch 187/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3629 - accuracy: 0.8392 - val_loss: 0.3734 - val_accuracy: 0.8351
# Epoch 188/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3642 - accuracy: 0.8393 - val_loss: 0.3721 - val_accuracy: 0.8353
# Epoch 189/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3638 - accuracy: 0.8389 - val_loss: 0.3712 - val_accuracy: 0.8357
# Epoch 190/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3647 - accuracy: 0.8388 - val_loss: 0.3742 - val_accuracy: 0.8363
# Epoch 191/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3649 - accuracy: 0.8383 - val_loss: 0.3737 - val_accuracy: 0.8357
# Epoch 192/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3635 - accuracy: 0.8397 - val_loss: 0.3728 - val_accuracy: 0.8358
# Epoch 193/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3637 - accuracy: 0.8400 - val_loss: 0.3713 - val_accuracy: 0.8357
# Epoch 194/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3631 - accuracy: 0.8394 - val_loss: 0.3728 - val_accuracy: 0.8353
# Epoch 195/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3642 - accuracy: 0.8385 - val_loss: 0.3717 - val_accuracy: 0.8365
# Epoch 196/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3633 - accuracy: 0.8398 - val_loss: 0.3725 - val_accuracy: 0.8368
# Epoch 197/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.3645 - accuracy: 0.8387 - val_loss: 0.3726 - val_accuracy: 0.8356
# Epoch 198/300
# 1683/1683 [==============================] - 89s 53ms/step - loss: 0.
300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3592 - accuracy: 0.8402 - val_loss: 0.3705 - val_accuracy: 0.8370
# Epoch 228/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3581 - accuracy: 0.8410 - val_loss: 0.3695 - val_accuracy: 0.8374
# Epoch 229/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3601 - accuracy: 0.8397 - val_loss: 0.3712 - val_accuracy: 0.8371
# Epoch 230/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3594 - accuracy: 0.8406 - val_loss: 0.3700 - val_accuracy: 0.8372
# Epoch 231/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3592 - accuracy: 0.8405 - val_loss: 0.3721 - val_accuracy: 0.8359
# Epoch 232/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3600 - accuracy: 0.8406 - val_loss: 0.3698 - val_accuracy: 0.8369
# Epoch 233/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3593 - accuracy: 0.8411 - val_loss: 0.3700 - val_accuracy: 0.8375
# Epoch 234/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3587 - accuracy: 0.8416 - val_loss: 0.3684 - val_accuracy: 0.8373
# Epoch 235/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3593 - accuracy: 0.8401 - val_loss: 0.3690 - val_accuracy: 0.8375
# Epoch 236/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3601 - accuracy: 0.8403 - val_loss: 0.3695 - val_accuracy: 0.8377
# Epoch 237/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3597 - accuracy: 0.8408 - val_loss: 0.3673 - val_accuracy: 0.8381
# Epoch 238/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3594 - accuracy: 0.8406 - val_loss: 0.3710 - val_accuracy: 0.8380
# Epoch 239/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3588 - accuracy: 0.8417 - val_loss: 0.3707 - val_accuracy: 0.8377
# Epoch 240/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3590 - accuracy: 0.8414 - val_loss: 0.3690 - val_accuracy: 0.8380
# Epoch 241/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3557 - accuracy: 0.8429 - val_loss: 0.3704 - val_accuracy: 0.8374
# Epoch 242/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3586 - accuracy: 0.8421 - val_loss: 0.3697 - val_accuracy: 0.8370
# Epoch 243/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3603 - accuracy: 0.8398 - val_loss: 0.3704 - val_accuracy: 0.8366
# Epoch 244/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3609 - accuracy: 0.8396 - val_loss: 0.3691 - val_accuracy: 0.8380
# Epoch 245/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3600 - accuracy: 0.8409 - val_loss: 0.3688 - val_accuracy: 0.8380
# Epoch 246/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3579 - accuracy: 0.8406 - val_loss: 0.3698 - val_accuracy: 0.8375
# Epoch 247/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3594 - accuracy: 0.8407 - val_loss: 0.3687 - val_accuracy: 0.8369
# Epoch 248/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3583 - accuracy: 0.8411 - val_loss: 0.3708 - val_accuracy: 0.8369
# Epoch 249/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3583 - accuracy: 0.8416 - val_loss: 0.3675 - val_accuracy: 0.8383
# Epoch 250/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3580 - accuracy: 0.8413 - val_loss: 0.3715 - val_accuracy: 0.8369
# Epoch 251/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3597 - accuracy: 0.8402 - val_loss: 0.3683 - val_accuracy: 0.8376
# Epoch 252/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3583 - accuracy: 0.8420 - val_loss: 0.3690 - val_accuracy: 0.8380
# Epoch 253/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3586 - accuracy: 0.8416 - val_loss: 0.3700 - val_accuracy: 0.8375
# Epoch 254/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3568 - accuracy: 0.8417 - val_loss: 0.3685 - val_accuracy: 0.8378
# Epoch 255/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3571 - accuracy: 0.8415 - val_loss: 0.3680 - val_accuracy: 0.8379
# Epoch 256/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3583 - accuracy: 0.8410 - val_loss: 0.3697 - val_accuracy: 0.8373
# Epoch 257/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3573 - accuracy: 0.8417 - val_loss: 0.3709 - val_accuracy: 0.8382
# Epoch 258/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3568 - accuracy: 0.8419 - val_loss: 0.3690 - val_accuracy: 0.8383
# Epoch 259/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3579 - accuracy: 0.8416 - val_loss: 0.3690 - val_accuracy: 0.8373
# Epoch 260/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3573 - accuracy: 0.8420 - val_loss: 0.3679 - val_accuracy: 0.8375
# Epoch 261/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3550 - accuracy: 0.8429 - val_loss: 0.3678 - val_accuracy: 0.8383
# Epoch 262/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3573 - accuracy: 0.8409 - val_loss: 0.3693 - val_accuracy: 0.8383
# Epoch 263/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3571 - accuracy: 0.8421 - val_loss: 0.3687 - val_accuracy: 0.8378
# Epoch 264/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3560 - accuracy: 0.8419 - val_loss: 0.3677 - val_accuracy: 0.8381
# Epoch 265/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3570 - accuracy: 0.8420 - val_loss: 0.3715 - val_accuracy: 0.8367
# Epoch 266/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3568 - accuracy: 0.8413 - val_loss: 0.3685 - val_accuracy: 0.8381
# Epoch 267/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3596 - accuracy: 0.8411 - val_loss: 0.3682 - val_accuracy: 0.8385
# Epoch 268/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3578 - accuracy: 0.8413 - val_loss: 0.3665 - val_accuracy: 0.8383
# Epoch 269/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3569 - accuracy: 0.8430 - val_loss: 0.3673 - val_accuracy: 0.8380
# Epoch 270/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3565 - accuracy: 0.8437 - val_loss: 0.3708 - val_accuracy: 0.8382
# Epoch 271/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3559 - accuracy: 0.8432 - val_loss: 0.3682 - val_accuracy: 0.8386
# Epoch 272/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3553 - accuracy: 0.8429 - val_loss: 0.3696 - val_accuracy: 0.8379
# Epoch 273/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3543 - accuracy: 0.8430 - val_loss: 0.3678 - val_accuracy: 0.8389
# Epoch 274/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3577 - accuracy: 0.8416 - val_loss: 0.3697 - val_accuracy: 0.8379
# Epoch 275/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3554 - accuracy: 0.8419 - val_loss: 0.3695 - val_accuracy: 0.8381
# Epoch 276/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3564 - accuracy: 0.8421 - val_loss: 0.3676 - val_accuracy: 0.8375
# Epoch 277/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3552 - accuracy: 0.8425 - val_loss: 0.3701 - val_accuracy: 0.8383
# Epoch 278/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3565 - accuracy: 0.8423 - val_loss: 0.3679 - val_accuracy: 0.8382
# Epoch 279/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3554 - accuracy: 0.8436 - val_loss: 0.3690 - val_accuracy: 0.8377
# Epoch 280/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3548 - accuracy: 0.8428 - val_loss: 0.3686 - val_accuracy: 0.8376
# Epoch 281/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3557 - accuracy: 0.8435 - val_loss: 0.3676 - val_accuracy: 0.8384
# Epoch 282/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3554 - accuracy: 0.8431 - val_loss: 0.3684 - val_accuracy: 0.8387
# Epoch 283/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3550 - accuracy: 0.8427 - val_loss: 0.3675 - val_accuracy: 0.8389
# Epoch 284/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3540 - accuracy: 0.8429 - val_loss: 0.3680 - val_accuracy: 0.8390
# Epoch 285/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3541 - accuracy: 0.8433 - val_loss: 0.3681 - val_accuracy: 0.8387
# Epoch 286/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3554 - accuracy: 0.8422 - val_loss: 0.3701 - val_accuracy: 0.8384
# Epoch 287/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3562 - accuracy: 0.8427 - val_loss: 0.3673 - val_accuracy: 0.8391
# Epoch 288/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3529 - accuracy: 0.8431 - val_loss: 0.3675 - val_accuracy: 0.8387
# Epoch 289/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3569 - accuracy: 0.8429 - val_loss: 0.3670 - val_accuracy: 0.8388
# Epoch 290/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3552 - accuracy: 0.8423 - val_loss: 0.3678 - val_accuracy: 0.8383
# Epoch 291/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3547 - accuracy: 0.8428 - val_loss: 0.3694 - val_accuracy: 0.8382
# Epoch 292/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3549 - accuracy: 0.8421 - val_loss: 0.3706 - val_accuracy: 0.8379
# Epoch 293/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3545 - accuracy: 0.8433 - val_loss: 0.3687 - val_accuracy: 0.8387
# Epoch 294/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3554 - accuracy: 0.8431 - val_loss: 0.3677 - val_accuracy: 0.8382
# Epoch 295/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3547 - accuracy: 0.8428 - val_loss: 0.3688 - val_accuracy: 0.8381
# Epoch 296/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3551 - accuracy: 0.8433 - val_loss: 0.3685 - val_accuracy: 0.8386
# Epoch 297/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3542 - accuracy: 0.8443 - val_loss: 0.3695 - val_accuracy: 0.8376
# Epoch 298/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3538 - accuracy: 0.8442 - val_loss: 0.3691 - val_accuracy: 0.8374
# Epoch 299/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3544 - accuracy: 0.8426 - val_loss: 0.3694 - val_accuracy: 0.8377
# Epoch 300/300
# 1683/1683 [==============================] - 87s 52ms/step - loss: 0.3543 - accuracy: 0.8424 - val_loss: 0.3696 - val_accuracy: 0.8385

# %%
plt.figure(figsize=(16,2))
plt.subplot(1,2,1)
plot_graphs(history, 'accuracy')
plt.subplot(1,2,2)
plot_graphs(history, 'loss')

# %% [markdown]
# # eval

# %%
test_loss, test_acc = model_high.evaluate([pep_test, aa_test, en_test, ec_test, e1_test, e2_test], y_test)
print('Test Loss: {}'.format(test_loss))
print('Test Accuracy: {}'.format(test_acc))

# prediction
y_pred = [1 if i>=0.5 else 0 for i in model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])]
print(classification_report(y_test, y_pred))
# AUC
probs = model_high.predict([pep_test, aa_test, en_test, ec_test, e1_test, e2_test])
rf_auc = roc_auc_score(y_test, probs)
print('rf auc : {}'.format(rf_auc))
# plot the roc curve for the model_high
rf_fpr, rf_tpr, _ = roc_curve(y_test, probs)
plt.figure(figsize=(4, 4))
plt.plot(rf_fpr, rf_tpr, marker='.', label='RF AUC = {:.4f}'.format(rf_auc), color='orange')
plt.title('ROC curve')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

cf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix, annot=True, fmt=',.0f')
plt.show()
plt.figure(figsize=(3, 3))
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
plt.show()
# Out:
# 2104/2104 [==============================] - 39s 18ms/step - loss: 0.3678 - accuracy: 0.8365
# Test Loss: 0.36779847741127014
# Test Accuracy: 0.8364587426185608
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84     33706
#            1       0.84      0.82      0.83     33592
#
#     accuracy                           0.84     67298
#    macro avg       0.84      0.84      0.84     67298
# weighted avg       0.84      0.84      0.84     67298
#
# rf auc : 0.9176092875483955

# %% [markdown]
# # digestibility Embedding Go!
#   - using pre trained protein language model
